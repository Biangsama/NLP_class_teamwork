# %% [markdown]
# > 本文是《使用PaddleNLP识别垃圾邮件》系列第四篇，该系列持续更新中……
# >
# > 系列背景介绍：[《使用PaddleNLP识别垃圾邮件》](https://aistudio.baidu.com/aistudio/projectdetail/1955576)系列项目，针对当前企业面临的垃圾邮件问题，尝试使用深度学习的方法，探索多语言垃圾邮件的内容、标题提取与分类识别。
# >
# > 该系列还有一个姊妹篇，[《使用PaddleNLP进行恶意网页识别》](https://aistudio.baidu.com/aistudio/projectdetail/1812025)，欢迎感兴趣的读者点进来交流评论。
# ![https://ai-studio-static-online.cdn.bcebos.com/d500f483e55544a5b929abad59de208f180c068cc81648009fab60a0b6d9bda2](https://ai-studio-static-online.cdn.bcebos.com/d500f483e55544a5b929abad59de208f180c068cc81648009fab60a0b6d9bda2)

# %% [markdown]
# # 系列目录
# - [使用PaddleNLP识别垃圾邮件（一）：准确率98.5%的垃圾邮件分类器](https://aistudio.baidu.com/aistudio/projectdetail/1955576)
#    - 使用PaddleNLP的文本分类LSTM模型，提取中文邮件内容判断邮件是否为垃圾邮件。
# - [使用PaddleNLP识别垃圾邮件（二）：用BERT做中文邮件内容分类](https://aistudio.baidu.com/aistudio/projectdetail/1988755)
# 	- 使用PaddleNLP的BERT预训练模型，根据提取的中文邮件内容判断邮件是否为垃圾邮件。
# - [使用PaddleNLP识别垃圾邮件（三）：用ELECTRA做英文邮件标题分类](https://aistudio.baidu.com/aistudio/projectdetail/1988755)
# 	- 介绍在Python中解析eml邮件内容的办法：email模块和mmpi库；
#    - 使用PaddleNLP的ELECTRA预训练模型，根据提取的英文邮件标题判断邮件是否为垃圾邮件。
# - [使用PaddleNLP识别垃圾邮件（四）：用RoBERTa做中文邮件标题分类](https://aistudio.baidu.com/aistudio/projectdetail/2066132)
#    - 升级到最新自定义数据集方法；
#    - 使用PaddleNLP模型库，大幅简化开发流程；
#    - 使用PaddleNLP的RoBERTa预训练模型，根据提取的中文邮件标题判断邮件是否为垃圾邮件；
#    - 完成完整的批量邮件分类部署流程。

# %% [markdown]
# # 背景知识
# ## RoBERTa算法
# - [RoBERTa: A Robustly Optimized BERT Pretraining Approach](https://arxiv.org/abs/1907.11692)
# - [RoBERTa项目中文地址：https://github.com/brightmart/roberta_zh](https://github.com/brightmart/roberta_zh)
#
# RoBERTa是BERT的改进版，通过改进训练任务和数据生成方式、训练更久、使用更大批次、使用更多数据等获得了SOTA的效果；可以用BERT直接加载。A Robustly Optimized BERT，顾名思义，就是简单粗暴的BERT调优……
#
# ![https://pic2.zhimg.com/v2-1706f34a31428e33df76579968a64eff_1440w.jpg?source=172ae18b](https://pic2.zhimg.com/v2-1706f34a31428e33df76579968a64eff_1440w.jpg?source=172ae18b)
#
# 在模型规模、算力和数据上，与BERT相比主要有以下几点改进：
#
# - 更大的模型参数量（论文提供的训练时间来看，模型使用 1024 块 V100 GPU 训练了 1 天的时间）
# - 更大bacth size。RoBERTa 在训练过程中使用了更大的bacth size。尝试过从 256 到 8000 不等的bacth size。
# - 更多的训练数据（包括：CC-NEWS 等在内的 160GB 纯文本。而最初的BERT使用16GB BookCorpus数据集和英语维基百科进行训练）
#
# 另外，RoBERTa在训练方法上有以下改进：
#
# - 去掉下一句预测(NSP)任务
# - 动态掩码。BERT 依赖随机掩码和预测 token。原版的 BERT 实现在数据预处理期间执行一次掩码，得到一个静态掩码。 而 RoBERTa 使用了动态掩码：每次向模型输入一个序列时都会生成新的掩码模式。这样，在大量数据不断输入的过程中，模型会逐渐适应不同的掩码策略，学习不同的语言表征。
# - 文本编码。Byte-Pair Encoding（BPE）是字符级和词级别表征的混合，支持处理自然语言语料库中的众多常见词汇。原版的 BERT 实现使用字符级别的 BPE 词汇，大小为 30K，是在利用启发式分词规则对输入进行预处理之后学得的。Facebook 研究者没有采用这种方式，而是考虑用更大的 byte 级别 BPE 词汇表来训练 BERT，这一词汇表包含 50K 的 subword 单元，且没有对输入作任何额外的预处理或分词。
#
# ## RoBERTa中文版
#
# RoBERTa中文版所指的中文预训练RoBERTa模型只指按照RoBERTa论文主要精神训练的模型。包括：
#
# ```
# 1、数据生成方式和任务改进：取消下一个句子预测，并且数据连续从一个文档中获得。
#
# 2、更大更多样性的数据：使用30G中文训练，包含3亿个句子，100亿个字(即token）。由新闻、社区讨论、多个百科，包罗万象，覆盖数十万个主题，所以数据具有多样性（为了更有多样性，可以可以加入网络书籍、小说、故事类文学、微博等）。
#
# 3、训练更久：总共训练了近20万，总共见过近16亿个训练数据(instance)； 在Cloud TPU v3-256 上训练了24小时，相当于在TPU v3-8(128G显存)上需要训练一个月。
#
# 4、更大批次：使用了超大（8k）的批次batch size。
#
# 5、调整优化器等超参数。
# ```
#
# 除以上外，RoBERTa中文版，使用了全词掩码(whole word mask)。在全词Mask中，如果一个完整的词的部分WordPiece子词被mask，则同属该词的其他部分也会被mask，即全词掩码。
#
# RoBERTa中并没有直接实现动态掩码。通过复制一个训练样本得到多份数据，每份数据使用不同掩码，并加大复制的分数，可间接得到动态掩码效果。
#
# ## PaddleNLP提供的RoBERTa预训练模型
# 在[PaddleNLP Transformer API](https://gitee.com/paddlepaddle/PaddleNLP/blob/develop/docs/transformers.md)中，提供了下面几种RoBERTa算法的预训练模型。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/c374e04164a547edbf91ea1a6811c1b8c79d6e3b6c2d4742897b17b10319a9e9)

# %% [markdown]
# # 数据集介绍
#
# [TREC 2006 Spam Track Public Corpora](https://plg.uwaterloo.ca/~gvcormac/treccorpus06/about.html)是一个公开的垃圾邮件语料库，由国际文本检索会议提供，分为英文数据集（trec06p）和中文数据集（trec06c），其中所含的邮件均来源于真实邮件保留了邮件的原有格式和内容。
#
# 除TREC 2006外，还有TREC 2005和TREC 2007的英文垃圾邮件数据集（对，没有中文），本项目中，仅使用TREC 2006提供的中文数据集进行演示。TREC 2005-2007的垃圾邮件数据集，均已整理在项目挂载的数据集中，感兴趣的读者可以自行fork。
#
# 文件目录形式：delay和full分别是一种垃圾邮件过滤器的过滤机制，full目录下，是理想的邮件分类结果，我们可以视为研究的标签。
# ```
# trec06c
# │
# └───data
# │   │   000
# │   │   001
# │   │   ...
# │   └───215
# └───delay
# │   │   index
# └───full
# │   │   index
# ```

# %% [markdown]
# # 一、环境配置
#
# 本项目基于Paddle 2.0 编写，如果你的环境不是本版本，请先参考官网[安装](https://www.paddlepaddle.org.cn/install/quick) Paddle 2.0 。

# %%
# 加载开源邮件快速检测工具库mmpi
# !pip install D:\LeStoreDownload\mmpi-0.2.3
# !pip install yara-python
# Out:
# Processing d:\lestoredownload\mmpi-0.2.3
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: olefile==0.46 in d:\pythonproject\.venv\lib\site-packages (from mmpi==0.2.3) (0.46)
# Requirement already satisfied: yara-python in d:\pythonproject\.venv\lib\site-packages (from mmpi==0.2.3) (4.5.1)
# Requirement already satisfied: colorama==0.4.6 in d:\pythonproject\.venv\lib\site-packages (from mmpi==0.2.3) (0.4.6)
# Requirement already satisfied: prettytable==3.6.0 in d:\pythonproject\.venv\lib\site-packages (from mmpi==0.2.3) (3.6.0)
# Requirement already satisfied: tqdm==4.62.3 in d:\pythonproject\.venv\lib\site-packages (from mmpi==0.2.3) (4.62.3)
# Requirement already satisfied: importlib-metadata in d:\pythonproject\.venv\lib\site-packages (from prettytable==3.6.0->mmpi==0.2.3) (6.7.0)
# Requirement already satisfied: wcwidth in d:\pythonproject\.venv\lib\site-packages (from prettytable==3.6.0->mmpi==0.2.3) (0.2.13)
# Requirement already satisfied: zipp>=0.5 in d:\pythonproject\.venv\lib\site-packages (from importlib-metadata->prettytable==3.6.0->mmpi==0.2.3) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\pythonproject\.venv\lib\site-packages (from importlib-metadata->prettytable==3.6.0->mmpi==0.2.3) (4.7.1)
# Building wheels for collected packages: mmpi
#   Building wheel for mmpi (setup.py): started
#   Building wheel for mmpi (setup.py): finished with status 'done'
#   Created wheel for mmpi: filename=mmpi-0.2.3-py3-none-any.whl size=90094 sha256=66c092091688334a08c6fc97e84b91260af1ec3c022b5c83661a77fa51b7b54f
#   Stored in directory: c:\users\biang\appdata\local\pip\cache\wheels\82\70\a5\7cc10589f58811e9c5db04e973fb1ceaac508cf07f6ce568bd
# Successfully built mmpi
# Installing collected packages: mmpi
#   Attempting uninstall: mmpi
#     Found existing installation: mmpi 0.2.3
#     Uninstalling mmpi-0.2.3:
#       Successfully uninstalled mmpi-0.2.3
# Successfully installed mmpi-0.2.3
# WARNING: Ignoring invalid distribution -addlepaddle (d:\pythonproject\.venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle (d:\pythonproject\.venv\lib\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: yara-python in d:\pythonproject\.venv\lib\site-packages (4.5.1)
# WARNING: Ignoring invalid distribution -addlepaddle (d:\pythonproject\.venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle (d:\pythonproject\.venv\lib\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 导入相关的模块
import numpy as np
import re
import jieba
import os 
import random
import paddle
import paddlenlp
from paddlenlp.data import Stack, Pad, Tuple
import paddle.nn.functional as F
import paddle.nn as nn
from visualdl import LogWriter
from functools import partial #partial()函数可以用来固定某些参数值，并返回一个新的callable对象
from tqdm import tqdm
from mmpi import mmpi

# %%
print(paddle.__version__)
# Out:
# 2.5.2

# %% [markdown]
# # 二、数据加载
#
# ## 2.1 数据集准备

# %%
# 解压数据集
# !tar xvf data/data89631/trec06c.tgz
# Out:
# x trec06c/
# x trec06c/data/
# x trec06c/data/101/
# x trec06c/data/101/252
# x trec06c/data/101/260
# x trec06c/data/101/101
# x trec06c/data/101/254
# x trec06c/data/101/262
# x trec06c/data/101/279
# x trec06c/data/101/037
# x trec06c/data/101/278
# x trec06c/data/101/186
# x trec06c/data/101/140
# x trec06c/data/101/049
# x trec06c/data/101/175
# x trec06c/data/101/093
# x trec06c/data/101/024
# x trec06c/data/101/230
# x trec06c/data/101/159
# x trec06c/data/101/160
# x trec06c/data/101/051
# x trec06c/data/101/184
# x trec06c/data/101/293
# x trec06c/data/101/238
# x trec06c/data/101/222
# x trec06c/data/101/044
# x trec06c/data/101/235
# x trec06c/data/101/183
# x trec06c/data/101/255
# x trec06c/data/101/152
# x trec06c/data/101/034
# x trec06c/data/101/216
# x trec06c/data/101/270
# x trec06c/data/101/109
# x trec06c/data/101/210
# x trec06c/data/101/054
# x trec06c/data/101/111
# x trec06c/data/101/149
# x trec06c/data/101/258
# x trec06c/data/101/032
# x trec06c/data/101/151
# x trec06c/data/101/023
# x trec06c/data/101/158
# x trec06c/data/101/143
# x trec06c/data/101/105
# x trec06c/data/101/122
# x trec06c/data/101/247
# x trec06c/data/101/009
# x trec06c/data/101/013
# x trec06c/data/101/104
# x trec06c/data/101/294
# x trec06c/data/101/144
# x trec06c/data/101/263
# x trec06c/data/101/145
# x trec06c/data/101/134
# x trec06c/data/101/098
# x trec06c/data/101/236
# x trec06c/data/101/046
# x trec06c/data/101/131
# x trec06c/data/101/006
# x trec06c/data/101/161
# x trec06c/data/101/198
# x trec06c/data/101/299
# x trec06c/data/101/138
# x trec06c/data/101/089
# x trec06c/data/101/187
# x trec06c/data/101/094
# x trec06c/data/101/179
# x trec06c/data/101/092
# x trec06c/data/101/033
# x trec06c/data/101/001
# x trec06c/data/101/267
# x trec06c/data/101/244
# x trec06c/data/101/225
# x trec06c/data/101/197
# x trec06c/data/101/085
# x trec06c/data/101/066
# x trec06c/data/101/077
# x trec06c/data/101/139
# x trec06c/data/101/058
# x trec06c/data/101/285
# x trec06c/data/101/251
# x trec06c/data/101/195
# x trec06c/data/101/015
# x trec06c/data/101/035
# x trec06c/data/101/154
# x trec06c/data/101/190
# x trec06c/data/101/067
# x trec06c/data/101/180
# x trec06c/data/101/272
# x trec06c/data/101/062
# x trec06c/data/101/155
# x trec06c/data/101/245
# x trec06c/data/101/061
# x trec06c/data/101/099
# x trec06c/data/101/199
# x trec06c/data/101/217
# x trec06c/data/101/295
# x trec06c/data/101/057
# x trec06c/data/101/291
# x trec06c/data/101/027
# x trec06c/data/101/215
# x trec06c/data/101/174
# x trec06c/data/101/028
# x trec06c/data/101/188
# x trec06c/data/101/194
# x trec06c/data/101/271
# x trec06c/data/101/038
# x trec06c/data/101/257
# x trec06c/data/101/202
# x trec06c/data/101/182
# x trec06c/data/101/298
# x trec06c/data/101/000
# x trec06c/data/101/053
# x trec06c/data/101/018
# x trec06c/data/101/102
# x trec06c/data/101/176
# x trec06c/data/101/203
# x trec06c/data/101/204
# x trec06c/data/101/219
# x trec06c/data/101/259
# x trec06c/data/101/243
# x trec06c/data/101/103
# x trec06c/data/101/265
# x trec06c/data/101/113
# x trec06c/data/101/282
# x trec06c/data/101/226
# x trec06c/data/101/168
# x trec06c/data/101/224
# x trec06c/data/101/207
# x trec06c/data/101/165
# x trec06c/data/101/136
# x trec06c/data/101/003
# x trec06c/data/101/065
# x trec06c/data/101/041
# x trec06c/data/101/189
# x trec06c/data/101/162
# x trec06c/data/101/068
# x trec06c/data/101/100
# x trec06c/data/101/005
# x trec06c/data/101/286
# x trec06c/data/101/181
# x trec06c/data/101/072
# x trec06c/data/101/129
# x trec06c/data/101/114
# x trec06c/data/101/248
# x trec06c/data/101/214
# x trec06c/data/101/268
# x trec06c/data/101/177
# x trec06c/data/101/090
# x trec06c/data/101/218
# x trec06c/data/101/008
# x trec06c/data/101/220
# x trec06c/data/101/237
# x trec06c/data/101/170
# x trec06c/data/101/106
# x trec06c/data/101/043
# x trec06c/data/101/080
# x trec06c/data/101/064
# x trec06c/data/101/055
# x trec06c/data/101/273
# x trec06c/data/101/004
# x trec06c/data/101/039
# x trec06c/data/101/036
# x trec06c/data/101/031
# x trec06c/data/101/169
# x trec06c/data/101/097
# x trec06c/data/101/022
# x trec06c/data/101/153
# x trec06c/data/101/297
# x trec06c/data/101/269
# x trec06c/data/101/050
# x trec06c/data/101/288
# x trec06c/data/101/075
# x trec06c/data/101/274
# x trec06c/data/101/073
# x trec06c/data/101/060
# x trec06c/data/101/192
# x trec06c/data/101/241
# x trec06c/data/101/026
# x trec06c/data/101/123
# x trec06c/data/101/233
# x trec06c/data/101/086
# x trec06c/data/101/012
# x trec06c/data/101/231
# x trec06c/data/101/117
# x trec06c/data/101/253
# x trec06c/data/101/146
# x trec06c/data/101/016
# x trec06c/data/101/240
# x trec06c/data/101/069
# x trec06c/data/101/221
# x trec06c/data/101/021
# x trec06c/data/101/125
# x trec06c/data/101/191
# x trec06c/data/101/087
# x trec06c/data/101/118
# x trec06c/data/101/119
# x trec06c/data/101/011
# x trec06c/data/101/071
# x trec06c/data/101/014
# x trec06c/data/101/082
# x trec06c/data/101/076
# x trec06c/data/101/150
# x trec06c/data/101/211
# x trec06c/data/101/059
# x trec06c/data/101/029
# x trec06c/data/101/173
# x trec06c/data/101/010
# x trec06c/data/101/148
# x trec06c/data/101/256
# x trec06c/data/101/172
# x trec06c/data/101/124
# x trec06c/data/101/296
# x trec06c/data/101/234
# x trec06c/data/101/167
# x trec06c/data/101/079
# x trec06c/data/101/227
# x trec06c/data/101/078
# x trec06c/data/101/277
# x trec06c/data/101/126
# x trec06c/data/101/185
# x trec06c/data/101/108
# x trec06c/data/101/290
# x trec06c/data/101/228
# x trec06c/data/101/246
# x trec06c/data/101/200
# x trec06c/data/101/284
# x trec06c/data/101/056
# x trec06c/data/101/212
# x trec06c/data/101/292
# x trec06c/data/101/116
# x trec06c/data/101/095
# x trec06c/data/101/127
# x trec06c/data/101/007
# x trec06c/data/101/052
# x trec06c/data/101/156
# x trec06c/data/101/083
# x trec06c/data/101/088
# x trec06c/data/101/084
# x trec06c/data/101/115
# x trec06c/data/101/157
# x trec06c/data/101/130
# x trec06c/data/101/281
# x trec06c/data/101/081
# x trec06c/data/101/206
# x trec06c/data/101/261
# x trec06c/data/101/264
# x trec06c/data/101/110
# x trec06c/data/101/213
# x trec06c/data/101/280
# x trec06c/data/101/070
# x trec06c/data/101/030
# x trec06c/data/101/045
# x trec06c/data/101/141
# x trec06c/data/101/147
# x trec06c/data/101/289
# x trec06c/data/101/135
# x trec06c/data/101/112
# x trec06c/data/101/276
# x trec06c/data/101/048
# x trec06c/data/101/091
# x trec06c/data/101/047
# x trec06c/data/101/096
# x trec06c/data/101/040
# x trec06c/data/101/107
# x trec06c/data/101/232
# x trec06c/data/101/002
# x trec06c/data/101/017
# x trec06c/data/101/209
# x trec06c/data/101/249
# x trec06c/data/101/283
# x trec06c/data/101/137
# x trec06c/data/101/164
# x trec06c/data/101/275
# x trec06c/data/101/196
# x trec06c/data/101/121
# x trec06c/data/101/120
# x trec06c/data/101/063
# x trec06c/data/101/193
# x trec06c/data/101/201
# x trec06c/data/101/239
# x trec06c/data/101/287
# x trec06c/data/101/025
# x trec06c/data/101/020
# x trec06c/data/101/229
# x trec06c/data/101/205
# x trec06c/data/101/242
# x trec06c/data/101/171
# x trec06c/data/101/019
# x trec06c/data/101/128
# x trec06c/data/101/042
# x trec06c/data/101/142
# x trec06c/data/101/208
# x trec06c/data/101/074
# x trec06c/data/101/178
# x trec06c/data/101/250
# x trec06c/data/101/133
# x trec06c/data/101/223
# x trec06c/data/101/166
# x trec06c/data/101/266
# x trec06c/data/101/132
# x trec06c/data/101/163
# x trec06c/data/037/
# x trec06c/data/037/252
# x trec06c/data/037/260
# x trec06c/data/037/101
# x trec06c/data/037/254
# x trec06c/data/037/262
# x trec06c/data/037/279
# x trec06c/data/037/037
# x trec06c/data/037/278
# x trec06c/data/037/186
# x trec06c/data/037/140
# x trec06c/data/037/049
# x trec06c/data/037/175
# x trec06c/data/037/093
# x trec06c/data/037/024
# x trec06c/data/037/230
# x trec06c/data/037/159
# x trec06c/data/037/160
# x trec06c/data/037/051
# x trec06c/data/037/184
# x trec06c/data/037/293
# x trec06c/data/037/238
# x trec06c/data/037/222
# x trec06c/data/037/044
# x trec06c/data/037/235
# x trec06c/data/037/183
# x trec06c/data/037/255
# x trec06c/data/037/152
# x trec06c/data/037/034
# x trec06c/data/037/216
# x trec06c/data/037/270
# x trec06c/data/037/109
# x trec06c/data/037/210
# x trec06c/data/037/054
# x trec06c/data/037/111
# x trec06c/data/037/149
# x trec06c/data/037/258
# x trec06c/data/037/032
# x trec06c/data/037/151
# x trec06c/data/037/023
# x trec06c/data/037/158
# x trec06c/data/037/143
# x trec06c/data/037/105
# x trec06c/data/037/122
# x trec06c/data/037/247
# x trec06c/data/037/009
# x trec06c/data/037/013
# x trec06c/data/037/104
# x trec06c/data/037/294
# x trec06c/data/037/144
# x trec06c/data/037/263
# x trec06c/data/037/145
# x trec06c/data/037/134
# x trec06c/data/037/098
# x trec06c/data/037/236
# x trec06c/data/037/046
# x trec06c/data/037/131
# x trec06c/data/037/006
# x trec06c/data/037/161
# x trec06c/data/037/198
# x trec06c/data/037/299
# x trec06c/data/037/138
# x trec06c/data/037/089
# x trec06c/data/037/187
# x trec06c/data/037/094
# x trec06c/data/037/179
# x trec06c/data/037/092
# x trec06c/data/037/033
# x trec06c/data/037/001
# x trec06c/data/037/267
# x trec06c/data/037/244
# x trec06c/data/037/225
# x trec06c/data/037/197
# x trec06c/data/037/085
# x trec06c/data/037/066
# x trec06c/data/037/077
# x trec06c/data/037/139
# x trec06c/data/037/058
# x trec06c/data/037/285
# x trec06c/data/037/251
# x trec06c/data/037/195
# x trec06c/data/037/015
# x trec06c/data/037/035
# x trec06c/data/037/154
# x trec06c/data/037/190
# x trec06c/data/037/067
# x trec06c/data/037/180
# x trec06c/data/037/272
# x trec06c/data/037/062
# x trec06c/data/037/155
# x trec06c/data/037/245
# x trec06c/data/037/061
# x trec06c/data/037/099
# x trec06c/data/037/199
# x trec06c/data/037/217
# x trec06c/data/037/295
# x trec06c/data/037/057
# x trec06c/data/037/291
# x trec06c/data/037/027
# x trec06c/data/037/215
# x trec06c/data/037/174
# x trec06c/data/037/028
# x trec06c/data/037/188
# x trec06c/data/037/194
# x trec06c/data/037/271
# x trec06c/data/037/038
# x trec06c/data/037/257
# x trec06c/data/037/202
# x trec06c/data/037/182
# x trec06c/data/037/298
# x trec06c/data/037/000
# x trec06c/data/037/053
# x trec06c/data/037/018
# x trec06c/data/037/102
# x trec06c/data/037/176
# x trec06c/data/037/203
# x trec06c/data/037/204
# x trec06c/data/037/219
# x trec06c/data/037/259
# x trec06c/data/037/243
# x trec06c/data/037/103
# x trec06c/data/037/265
# x trec06c/data/037/113
# x trec06c/data/037/282
# x trec06c/data/037/226
# x trec06c/data/037/168
# x trec06c/data/037/224
# x trec06c/data/037/207
# x trec06c/data/037/165
# x trec06c/data/037/136
# x trec06c/data/037/003
# x trec06c/data/037/065
# x trec06c/data/037/041
# x trec06c/data/037/189
# x trec06c/data/037/162
# x trec06c/data/037/068
# x trec06c/data/037/100
# x trec06c/data/037/005
# x trec06c/data/037/286
# x trec06c/data/037/181
# x trec06c/data/037/072
# x trec06c/data/037/129
# x trec06c/data/037/114
# x trec06c/data/037/248
# x trec06c/data/037/214
# x trec06c/data/037/268
# x trec06c/data/037/177
# x trec06c/data/037/090
# x trec06c/data/037/218
# x trec06c/data/037/008
# x trec06c/data/037/220
# x trec06c/data/037/237
# x trec06c/data/037/170
# x trec06c/data/037/106
# x trec06c/data/037/043
# x trec06c/data/037/080
# x trec06c/data/037/064
# x trec06c/data/037/055
# x trec06c/data/037/273
# x trec06c/data/037/004
# x trec06c/data/037/039
# x trec06c/data/037/036
# x trec06c/data/037/031
# x trec06c/data/037/169
# x trec06c/data/037/097
# x trec06c/data/037/022
# x trec06c/data/037/153
# x trec06c/data/037/297
# x trec06c/data/037/269
# x trec06c/data/037/050
# x trec06c/data/037/288
# x trec06c/data/037/075
# x trec06c/data/037/274
# x trec06c/data/037/073
# x trec06c/data/037/060
# x trec06c/data/037/192
# x trec06c/data/037/241
# x trec06c/data/037/026
# x trec06c/data/037/123
# x trec06c/data/037/233
# x trec06c/data/037/086
# x trec06c/data/037/012
# x trec06c/data/037/231
# x trec06c/data/037/117
# x trec06c/data/037/253
# x trec06c/data/037/146
# x trec06c/data/037/016
# x trec06c/data/037/240
# x trec06c/data/037/069
# x trec06c/data/037/221
# x trec06c/data/037/021
# x trec06c/data/037/125
# x trec06c/data/037/191
# x trec06c/data/037/087
# x trec06c/data/037/118
# x trec06c/data/037/119
# x trec06c/data/037/011
# x trec06c/data/037/071
# x trec06c/data/037/014
# x trec06c/data/037/082
# x trec06c/data/037/076
# x trec06c/data/037/150
# x trec06c/data/037/211
# x trec06c/data/037/059
# x trec06c/data/037/029
# x trec06c/data/037/173
# x trec06c/data/037/010
# x trec06c/data/037/148
# x trec06c/data/037/256
# x trec06c/data/037/172
# x trec06c/data/037/124
# x trec06c/data/037/296
# x trec06c/data/037/234
# x trec06c/data/037/167
# x trec06c/data/037/079
# x trec06c/data/037/227
# x trec06c/data/037/078
# x trec06c/data/037/277
# x trec06c/data/037/126
# x trec06c/data/037/185
# x trec06c/data/037/108
# x trec06c/data/037/290
# x trec06c/data/037/228
# x trec06c/data/037/246
# x trec06c/data/037/200
# x trec06c/data/037/284
# x trec06c/data/037/056
# x trec06c/data/037/212
# x trec06c/data/037/292
# x trec06c/data/037/116
# x trec06c/data/037/095
# x trec06c/data/037/127
# x trec06c/data/037/007
# x trec06c/data/037/052
# x trec06c/data/037/156
# x trec06c/data/037/083
# x trec06c/data/037/088
# x trec06c/data/037/084
# x trec06c/data/037/115
# x trec06c/data/037/157
# x trec06c/data/037/130
# x trec06c/data/037/281
# x trec06c/data/037/081
# x trec06c/data/037/206
# x trec06c/data/037/261
# x trec06c/data/037/264
# x trec06c/data/037/110
# x trec06c/data/037/213
# x trec06c/data/037/280
# x trec06c/data/037/070
# x trec06c/data/037/030
# x trec06c/data/037/045
# x trec06c/data/037/141
# x trec06c/data/037/147
# x trec06c/data/037/289
# x trec06c/data/037/135
# x trec06c/data/037/112
# x trec06c/data/037/276
# x trec06c/data/037/048
# x trec06c/data/037/091
# x trec06c/data/037/047
# x trec06c/data/037/096
# x trec06c/data/037/040
# x trec06c/data/037/107
# x trec06c/data/037/232
# x trec06c/data/037/002
# x trec06c/data/037/017
# x trec06c/data/037/209
# x trec06c/data/037/249
# x trec06c/data/037/283
# x trec06c/data/037/137
# x trec06c/data/037/164
# x trec06c/data/037/275
# x trec06c/data/037/196
# x trec06c/data/037/121
# x trec06c/data/037/120
# x trec06c/data/037/063
# x trec06c/data/037/193
# x trec06c/data/037/201
# x trec06c/data/037/239
# x trec06c/data/037/287
# x trec06c/data/037/025
# x trec06c/data/037/020
# x trec06c/data/037/229
# x trec06c/data/037/205
# x trec06c/data/037/242
# x trec06c/data/037/171
# x trec06c/data/037/019
# x trec06c/data/037/128
# x trec06c/data/037/042
# x trec06c/data/037/142
# x trec06c/data/037/208
# x trec06c/data/037/074
# x trec06c/data/037/178
# x trec06c/data/037/250
# x trec06c/data/037/133
# x trec06c/data/037/223
# x trec06c/data/037/166
# x trec06c/data/037/266
# x trec06c/data/037/132
# x trec06c/data/037/163
# x trec06c/data/186/
# x trec06c/data/186/252
# x trec06c/data/186/260
# x trec06c/data/186/101
# x trec06c/data/186/254
# x trec06c/data/186/262
# x trec06c/data/186/279
# x trec06c/data/186/037
# x trec06c/data/186/278
# x trec06c/data/186/186
# x trec06c/data/186/140
# x trec06c/data/186/049
# x trec06c/data/186/175
# x trec06c/data/186/093
# x trec06c/data/186/024
# x trec06c/data/186/230
# x trec06c/data/186/159
# x trec06c/data/186/160
# x trec06c/data/186/051
# x trec06c/data/186/184
# x trec06c/data/186/293
# x trec06c/data/186/238
# x trec06c/data/186/222
# x trec06c/data/186/044
# x trec06c/data/186/235
# x trec06c/data/186/183
# x trec06c/data/186/255
# x trec06c/data/186/152
# x trec06c/data/186/034
# x trec06c/data/186/216
# x trec06c/data/186/270
# x trec06c/data/186/109
# x trec06c/data/186/210
# x trec06c/data/186/054
# x trec06c/data/186/111
# x trec06c/data/186/149
# x trec06c/data/186/258
# x trec06c/data/186/032
# x trec06c/data/186/151
# x trec06c/data/186/023
# x trec06c/data/186/158
# x trec06c/data/186/143
# x trec06c/data/186/105
# x trec06c/data/186/122
# x trec06c/data/186/247
# x trec06c/data/186/009
# x trec06c/data/186/013
# x trec06c/data/186/104
# x trec06c/data/186/294
# x trec06c/data/186/144
# x trec06c/data/186/263
# x trec06c/data/186/145
# x trec06c/data/186/134
# x trec06c/data/186/098
# x trec06c/data/186/236
# x trec06c/data/186/046
# x trec06c/data/186/131
# x trec06c/data/186/006
# x trec06c/data/186/161
# x trec06c/data/186/198
# x trec06c/data/186/299
# x trec06c/data/186/138
# x trec06c/data/186/089
# x trec06c/data/186/187
# x trec06c/data/186/094
# x trec06c/data/186/179
# x trec06c/data/186/092
# x trec06c/data/186/033
# x trec06c/data/186/001
# x trec06c/data/186/267
# x trec06c/data/186/244
# x trec06c/data/186/225
# x trec06c/data/186/197
# x trec06c/data/186/085
# x trec06c/data/186/066
# x trec06c/data/186/077
# x trec06c/data/186/139
# x trec06c/data/186/058
# x trec06c/data/186/285
# x trec06c/data/186/251
# x trec06c/data/186/195
# x trec06c/data/186/015
# x trec06c/data/186/035
# x trec06c/data/186/154
# x trec06c/data/186/190
# x trec06c/data/186/067
# x trec06c/data/186/180
# x trec06c/data/186/272
# x trec06c/data/186/062
# x trec06c/data/186/155
# x trec06c/data/186/245
# x trec06c/data/186/061
# x trec06c/data/186/099
# x trec06c/data/186/199
# x trec06c/data/186/217
# x trec06c/data/186/295
# x trec06c/data/186/057
# x trec06c/data/186/291
# x trec06c/data/186/027
# x trec06c/data/186/215
# x trec06c/data/186/174
# x trec06c/data/186/028
# x trec06c/data/186/188
# x trec06c/data/186/194
# x trec06c/data/186/271
# x trec06c/data/186/038
# x trec06c/data/186/257
# x trec06c/data/186/202
# x trec06c/data/186/182
# x trec06c/data/186/298
# x trec06c/data/186/000
# x trec06c/data/186/053
# x trec06c/data/186/018
# x trec06c/data/186/102
# x trec06c/data/186/176
# x trec06c/data/186/203
# x trec06c/data/186/204
# x trec06c/data/186/219
# x trec06c/data/186/259
# x trec06c/data/186/243
# x trec06c/data/186/103
# x trec06c/data/186/265
# x trec06c/data/186/113
# x trec06c/data/186/282
# x trec06c/data/186/226
# x trec06c/data/186/168
# x trec06c/data/186/224
# x trec06c/data/186/207
# x trec06c/data/186/165
# x trec06c/data/186/136
# x trec06c/data/186/003
# x trec06c/data/186/065
# x trec06c/data/186/041
# x trec06c/data/186/189
# x trec06c/data/186/162
# x trec06c/data/186/068
# x trec06c/data/186/100
# x trec06c/data/186/005
# x trec06c/data/186/286
# x trec06c/data/186/181
# x trec06c/data/186/072
# x trec06c/data/186/129
# x trec06c/data/186/114
# x trec06c/data/186/248
# x trec06c/data/186/214
# x trec06c/data/186/268
# x trec06c/data/186/177
# x trec06c/data/186/090
# x trec06c/data/186/218
# x trec06c/data/186/008
# x trec06c/data/186/220
# x trec06c/data/186/237
# x trec06c/data/186/170
# x trec06c/data/186/106
# x trec06c/data/186/043
# x trec06c/data/186/080
# x trec06c/data/186/064
# x trec06c/data/186/055
# x trec06c/data/186/273
# x trec06c/data/186/004
# x trec06c/data/186/039
# x trec06c/data/186/036
# x trec06c/data/186/031
# x trec06c/data/186/169
# x trec06c/data/186/097
# x trec06c/data/186/022
# x trec06c/data/186/153
# x trec06c/data/186/297
# x trec06c/data/186/269
# x trec06c/data/186/050
# x trec06c/data/186/288
# x trec06c/data/186/075
# x trec06c/data/186/274
# x trec06c/data/186/073
# x trec06c/data/186/060
# x trec06c/data/186/192
# x trec06c/data/186/241
# x trec06c/data/186/026
# x trec06c/data/186/123
# x trec06c/data/186/233
# x trec06c/data/186/086
# x trec06c/data/186/012
# x trec06c/data/186/231
# x trec06c/data/186/117
# x trec06c/data/186/253
# x trec06c/data/186/146
# x trec06c/data/186/016
# x trec06c/data/186/240
# x trec06c/data/186/069
# x trec06c/data/186/221
# x trec06c/data/186/021
# x trec06c/data/186/125
# x trec06c/data/186/191
# x trec06c/data/186/087
# x trec06c/data/186/118
# x trec06c/data/186/119
# x trec06c/data/186/011
# x trec06c/data/186/071
# x trec06c/data/186/014
# x trec06c/data/186/082
# x trec06c/data/186/076
# x trec06c/data/186/150
# x trec06c/data/186/211
# x trec06c/data/186/059
# x trec06c/data/186/029
# x trec06c/data/186/173
# x trec06c/data/186/010
# x trec06c/data/186/148
# x trec06c/data/186/256
# x trec06c/data/186/172
# x trec06c/data/186/124
# x trec06c/data/186/296
# x trec06c/data/186/234
# x trec06c/data/186/167
# x trec06c/data/186/079
# x trec06c/data/186/227
# x trec06c/data/186/078
# x trec06c/data/186/277
# x trec06c/data/186/126
# x trec06c/data/186/185
# x trec06c/data/186/108
# x trec06c/data/186/290
# x trec06c/data/186/228
# x trec06c/data/186/246
# x trec06c/data/186/200
# x trec06c/data/186/284
# x trec06c/data/186/056
# x trec06c/data/186/212
# x trec06c/data/186/292
# x trec06c/data/186/116
# x trec06c/data/186/095
# x trec06c/data/186/127
# x trec06c/data/186/007
# x trec06c/data/186/052
# x trec06c/data/186/156
# x trec06c/data/186/083
# x trec06c/data/186/088
# x trec06c/data/186/084
# x trec06c/data/186/115
# x trec06c/data/186/157
# x trec06c/data/186/130
# x trec06c/data/186/281
# x trec06c/data/186/081
# x trec06c/data/186/206
# x trec06c/data/186/261
# x trec06c/data/186/264
# x trec06c/data/186/110
# x trec06c/data/186/213
# x trec06c/data/186/280
# x trec06c/data/186/070
# x trec06c/data/186/030
# x trec06c/data/186/045
# x trec06c/data/186/141
# x trec06c/data/186/147
# x trec06c/data/186/289
# x trec06c/data/186/135
# x trec06c/data/186/112
# x trec06c/data/186/276
# x trec06c/data/186/048
# x trec06c/data/186/091
# x trec06c/data/186/047
# x trec06c/data/186/096
# x trec06c/data/186/040
# x trec06c/data/186/107
# x trec06c/data/186/232
# x trec06c/data/186/002
# x trec06c/data/186/017
# x trec06c/data/186/209
# x trec06c/data/186/249
# x trec06c/data/186/283
# x trec06c/data/186/137
# x trec06c/data/186/164
# x trec06c/data/186/275
# x trec06c/data/186/196
# x trec06c/data/186/121
# x trec06c/data/186/120
# x trec06c/data/186/063
# x trec06c/data/186/193
# x trec06c/data/186/201
# x trec06c/data/186/239
# x trec06c/data/186/287
# x trec06c/data/186/025
# x trec06c/data/186/020
# x trec06c/data/186/229
# x trec06c/data/186/205
# x trec06c/data/186/242
# x trec06c/data/186/171
# x trec06c/data/186/019
# x trec06c/data/186/128
# x trec06c/data/186/042
# x trec06c/data/186/142
# x trec06c/data/186/208
# x trec06c/data/186/074
# x trec06c/data/186/178
# x trec06c/data/186/250
# x trec06c/data/186/133
# x trec06c/data/186/223
# x trec06c/data/186/166
# x trec06c/data/186/266
# x trec06c/data/186/132
# x trec06c/data/186/163
# x trec06c/data/140/
# x trec06c/data/140/252
# x trec06c/data/140/260
# x trec06c/data/140/101
# x trec06c/data/140/254
# x trec06c/data/140/262
# x trec06c/data/140/279
# x trec06c/data/140/037
# x trec06c/data/140/278
# x trec06c/data/140/186
# x trec06c/data/140/140
# x trec06c/data/140/049
# x trec06c/data/140/175
# x trec06c/data/140/093
# x trec06c/data/140/024
# x trec06c/data/140/230
# x trec06c/data/140/159
# x trec06c/data/140/160
# x trec06c/data/140/051
# x trec06c/data/140/184
# x trec06c/data/140/293
# x trec06c/data/140/238
# x trec06c/data/140/222
# x trec06c/data/140/044
# x trec06c/data/140/235
# x trec06c/data/140/183
# x trec06c/data/140/255
# x trec06c/data/140/152
# x trec06c/data/140/034
# x trec06c/data/140/216
# x trec06c/data/140/270
# x trec06c/data/140/109
# x trec06c/data/140/210
# x trec06c/data/140/054
# x trec06c/data/140/111
# x trec06c/data/140/149
# x trec06c/data/140/258
# x trec06c/data/140/032
# x trec06c/data/140/151
# x trec06c/data/140/023
# x trec06c/data/140/158
# x trec06c/data/140/143
# x trec06c/data/140/105
# x trec06c/data/140/122
# x trec06c/data/140/247
# x trec06c/data/140/009
# x trec06c/data/140/013
# x trec06c/data/140/104
# x trec06c/data/140/294
# x trec06c/data/140/144
# x trec06c/data/140/263
# x trec06c/data/140/145
# x trec06c/data/140/134
# x trec06c/data/140/098
# x trec06c/data/140/236
# x trec06c/data/140/046
# x trec06c/data/140/131
# x trec06c/data/140/006
# x trec06c/data/140/161
# x trec06c/data/140/198
# x trec06c/data/140/299
# x trec06c/data/140/138
# x trec06c/data/140/089
# x trec06c/data/140/187
# x trec06c/data/140/094
# x trec06c/data/140/179
# x trec06c/data/140/092
# x trec06c/data/140/033
# x trec06c/data/140/001
# x trec06c/data/140/267
# x trec06c/data/140/244
# x trec06c/data/140/225
# x trec06c/data/140/197
# x trec06c/data/140/085
# x trec06c/data/140/066
# x trec06c/data/140/077
# x trec06c/data/140/139
# x trec06c/data/140/058
# x trec06c/data/140/285
# x trec06c/data/140/251
# x trec06c/data/140/195
# x trec06c/data/140/015
# x trec06c/data/140/035
# x trec06c/data/140/154
# x trec06c/data/140/190
# x trec06c/data/140/067
# x trec06c/data/140/180
# x trec06c/data/140/272
# x trec06c/data/140/062
# x trec06c/data/140/155
# x trec06c/data/140/245
# x trec06c/data/140/061
# x trec06c/data/140/099
# x trec06c/data/140/199
# x trec06c/data/140/217
# x trec06c/data/140/295
# x trec06c/data/140/057
# x trec06c/data/140/291
# x trec06c/data/140/027
# x trec06c/data/140/215
# x trec06c/data/140/174
# x trec06c/data/140/028
# x trec06c/data/140/188
# x trec06c/data/140/194
# x trec06c/data/140/271
# x trec06c/data/140/038
# x trec06c/data/140/257
# x trec06c/data/140/202
# x trec06c/data/140/182
# x trec06c/data/140/298
# x trec06c/data/140/000
# x trec06c/data/140/053
# x trec06c/data/140/018
# x trec06c/data/140/102
# x trec06c/data/140/176
# x trec06c/data/140/203
# x trec06c/data/140/204
# x trec06c/data/140/219
# x trec06c/data/140/259
# x trec06c/data/140/243
# x trec06c/data/140/103
# x trec06c/data/140/265
# x trec06c/data/140/113
# x trec06c/data/140/282
# x trec06c/data/140/226
# x trec06c/data/140/168
# x trec06c/data/140/224
# x trec06c/data/140/207
# x trec06c/data/140/165
# x trec06c/data/140/136
# x trec06c/data/140/003
# x trec06c/data/140/065
# x trec06c/data/140/041
# x trec06c/data/140/189
# x trec06c/data/140/162
# x trec06c/data/140/068
# x trec06c/data/140/100
# x trec06c/data/140/005
# x trec06c/data/140/286
# x trec06c/data/140/181
# x trec06c/data/140/072
# x trec06c/data/140/129
# x trec06c/data/140/114
# x trec06c/data/140/248
# x trec06c/data/140/214
# x trec06c/data/140/268
# x trec06c/data/140/177
# x trec06c/data/140/090
# x trec06c/data/140/218
# x trec06c/data/140/008
# x trec06c/data/140/220
# x trec06c/data/140/237
# x trec06c/data/140/170
# x trec06c/data/140/106
# x trec06c/data/140/043
# x trec06c/data/140/080
# x trec06c/data/140/064
# x trec06c/data/140/055
# x trec06c/data/140/273
# x trec06c/data/140/004
# x trec06c/data/140/039
# x trec06c/data/140/036
# x trec06c/data/140/031
# x trec06c/data/140/169
# x trec06c/data/140/097
# x trec06c/data/140/022
# x trec06c/data/140/153
# x trec06c/data/140/297
# x trec06c/data/140/269
# x trec06c/data/140/050
# x trec06c/data/140/288
# x trec06c/data/140/075
# x trec06c/data/140/274
# x trec06c/data/140/073
# x trec06c/data/140/060
# x trec06c/data/140/192
# x trec06c/data/140/241
# x trec06c/data/140/026
# x trec06c/data/140/123
# x trec06c/data/140/233
# x trec06c/data/140/086
# x trec06c/data/140/012
# x trec06c/data/140/231
# x trec06c/data/140/117
# x trec06c/data/140/253
# x trec06c/data/140/146
# x trec06c/data/140/016
# x trec06c/data/140/240
# x trec06c/data/140/069
# x trec06c/data/140/221
# x trec06c/data/140/021
# x trec06c/data/140/125
# x trec06c/data/140/191
# x trec06c/data/140/087
# x trec06c/data/140/118
# x trec06c/data/140/119
# x trec06c/data/140/011
# x trec06c/data/140/071
# x trec06c/data/140/014
# x trec06c/data/140/082
# x trec06c/data/140/076
# x trec06c/data/140/150
# x trec06c/data/140/211
# x trec06c/data/140/059
# x trec06c/data/140/029
# x trec06c/data/140/173
# x trec06c/data/140/010
# x trec06c/data/140/148
# x trec06c/data/140/256
# x trec06c/data/140/172
# x trec06c/data/140/124
# x trec06c/data/140/296
# x trec06c/data/140/234
# x trec06c/data/140/167
# x trec06c/data/140/079
# x trec06c/data/140/227
# x trec06c/data/140/078
# x trec06c/data/140/277
# x trec06c/data/140/126
# x trec06c/data/140/185
# x trec06c/data/140/108
# x trec06c/data/140/290
# x trec06c/data/140/228
# x trec06c/data/140/246
# x trec06c/data/140/200
# x trec06c/data/140/284
# x trec06c/data/140/056
# x trec06c/data/140/212
# x trec06c/data/140/292
# x trec06c/data/140/116
# x trec06c/data/140/095
# x trec06c/data/140/127
# x trec06c/data/140/007
# x trec06c/data/140/052
# x trec06c/data/140/156
# x trec06c/data/140/083
# x trec06c/data/140/088
# x trec06c/data/140/084
# x trec06c/data/140/115
# x trec06c/data/140/157
# x trec06c/data/140/130
# x trec06c/data/140/281
# x trec06c/data/140/081
# x trec06c/data/140/206
# x trec06c/data/140/261
# x trec06c/data/140/264
# x trec06c/data/140/110
# x trec06c/data/140/213
# x trec06c/data/140/280
# x trec06c/data/140/070
# x trec06c/data/140/030
# x trec06c/data/140/045
# x trec06c/data/140/141
# x trec06c/data/140/147
# x trec06c/data/140/289
# x trec06c/data/140/135
# x trec06c/data/140/112
# x trec06c/data/140/276
# x trec06c/data/140/048
# x trec06c/data/140/091
# x trec06c/data/140/047
# x trec06c/data/140/096
# x trec06c/data/140/040
# x trec06c/data/140/107
# x trec06c/data/140/232
# x trec06c/data/140/002
# x trec06c/data/140/017
# x trec06c/data/140/209
# x trec06c/data/140/249
# x trec06c/data/140/283
# x trec06c/data/140/137
# x trec06c/data/140/164
# x trec06c/data/140/275
# x trec06c/data/140/196
# x trec06c/data/140/121
# x trec06c/data/140/120
# x trec06c/data/140/063
# x trec06c/data/140/193
# x trec06c/data/140/201
# x trec06c/data/140/239
# x trec06c/data/140/287
# x trec06c/data/140/025
# x trec06c/data/140/020
# x trec06c/data/140/229
# x trec06c/data/140/205
# x trec06c/data/140/242
# x trec06c/data/140/171
# x trec06c/data/140/019
# x trec06c/data/140/128
# x trec06c/data/140/042
# x trec06c/data/140/142
# x trec06c/data/140/208
# x trec06c/data/140/074
# x trec06c/data/140/178
# x trec06c/data/140/250
# x trec06c/data/140/133
# x trec06c/data/140/223
# x trec06c/data/140/166
# x trec06c/data/140/266
# x trec06c/data/140/132
# x trec06c/data/140/163
# x trec06c/data/049/
# x trec06c/data/049/252
# x trec06c/data/049/260
# x trec06c/data/049/101
# x trec06c/data/049/254
# x trec06c/data/049/262
# x trec06c/data/049/279
# x trec06c/data/049/037
# x trec06c/data/049/278
# x trec06c/data/049/186
# x trec06c/data/049/140
# x trec06c/data/049/049
# x trec06c/data/049/175
# x trec06c/data/049/093
# x trec06c/data/049/024
# x trec06c/data/049/230
# x trec06c/data/049/159
# x trec06c/data/049/160
# x trec06c/data/049/051
# x trec06c/data/049/184
# x trec06c/data/049/293
# x trec06c/data/049/238
# x trec06c/data/049/222
# x trec06c/data/049/044
# x trec06c/data/049/235
# x trec06c/data/049/183
# x trec06c/data/049/255
# x trec06c/data/049/152
# x trec06c/data/049/034
# x trec06c/data/049/216
# x trec06c/data/049/270
# x trec06c/data/049/109
# x trec06c/data/049/210
# x trec06c/data/049/054
# x trec06c/data/049/111
# x trec06c/data/049/149
# x trec06c/data/049/258
# x trec06c/data/049/032
# x trec06c/data/049/151
# x trec06c/data/049/023
# x trec06c/data/049/158
# x trec06c/data/049/143
# x trec06c/data/049/105
# x trec06c/data/049/122
# x trec06c/data/049/247
# x trec06c/data/049/009
# x trec06c/data/049/013
# x trec06c/data/049/104
# x trec06c/data/049/294
# x trec06c/data/049/144
# x trec06c/data/049/263
# x trec06c/data/049/145
# x trec06c/data/049/134
# x trec06c/data/049/098
# x trec06c/data/049/236
# x trec06c/data/049/046
# x trec06c/data/049/131
# x trec06c/data/049/006
# x trec06c/data/049/161
# x trec06c/data/049/198
# x trec06c/data/049/299
# x trec06c/data/049/138
# x trec06c/data/049/089
# x trec06c/data/049/187
# x trec06c/data/049/094
# x trec06c/data/049/179
# x trec06c/data/049/092
# x trec06c/data/049/033
# x trec06c/data/049/001
# x trec06c/data/049/267
# x trec06c/data/049/244
# x trec06c/data/049/225
# x trec06c/data/049/197
# x trec06c/data/049/085
# x trec06c/data/049/066
# x trec06c/data/049/077
# x trec06c/data/049/139
# x trec06c/data/049/058
# x trec06c/data/049/285
# x trec06c/data/049/251
# x trec06c/data/049/195
# x trec06c/data/049/015
# x trec06c/data/049/035
# x trec06c/data/049/154
# x trec06c/data/049/190
# x trec06c/data/049/067
# x trec06c/data/049/180
# x trec06c/data/049/272
# x trec06c/data/049/062
# x trec06c/data/049/155
# x trec06c/data/049/245
# x trec06c/data/049/061
# x trec06c/data/049/099
# x trec06c/data/049/199
# x trec06c/data/049/217
# x trec06c/data/049/295
# x trec06c/data/049/057
# x trec06c/data/049/291
# x trec06c/data/049/027
# x trec06c/data/049/215
# x trec06c/data/049/174
# x trec06c/data/049/028
# x trec06c/data/049/188
# x trec06c/data/049/194
# x trec06c/data/049/271
# x trec06c/data/049/038
# x trec06c/data/049/257
# x trec06c/data/049/202
# x trec06c/data/049/182
# x trec06c/data/049/298
# x trec06c/data/049/000
# x trec06c/data/049/053
# x trec06c/data/049/018
# x trec06c/data/049/102
# x trec06c/data/049/176
# x trec06c/data/049/203
# x trec06c/data/049/204
# x trec06c/data/049/219
# x trec06c/data/049/259
# x trec06c/data/049/243
# x trec06c/data/049/103
# x trec06c/data/049/265
# x trec06c/data/049/113
# x trec06c/data/049/282
# x trec06c/data/049/226
# x trec06c/data/049/168
# x trec06c/data/049/224
# x trec06c/data/049/207
# x trec06c/data/049/165
# x trec06c/data/049/136
# x trec06c/data/049/003
# x trec06c/data/049/065
# x trec06c/data/049/041
# x trec06c/data/049/189
# x trec06c/data/049/162
# x trec06c/data/049/068
# x trec06c/data/049/100
# x trec06c/data/049/005
# x trec06c/data/049/286
# x trec06c/data/049/181
# x trec06c/data/049/072
# x trec06c/data/049/129
# x trec06c/data/049/114
# x trec06c/data/049/248
# x trec06c/data/049/214
# x trec06c/data/049/268
# x trec06c/data/049/177
# x trec06c/data/049/090
# x trec06c/data/049/218
# x trec06c/data/049/008
# x trec06c/data/049/220
# x trec06c/data/049/237
# x trec06c/data/049/170
# x trec06c/data/049/106
# x trec06c/data/049/043
# x trec06c/data/049/080
# x trec06c/data/049/064
# x trec06c/data/049/055
# x trec06c/data/049/273
# x trec06c/data/049/004
# x trec06c/data/049/039
# x trec06c/data/049/036
# x trec06c/data/049/031
# x trec06c/data/049/169
# x trec06c/data/049/097
# x trec06c/data/049/022
# x trec06c/data/049/153
# x trec06c/data/049/297
# x trec06c/data/049/269
# x trec06c/data/049/050
# x trec06c/data/049/288
# x trec06c/data/049/075
# x trec06c/data/049/274
# x trec06c/data/049/073
# x trec06c/data/049/060
# x trec06c/data/049/192
# x trec06c/data/049/241
# x trec06c/data/049/026
# x trec06c/data/049/123
# x trec06c/data/049/233
# x trec06c/data/049/086
# x trec06c/data/049/012
# x trec06c/data/049/231
# x trec06c/data/049/117
# x trec06c/data/049/253
# x trec06c/data/049/146
# x trec06c/data/049/016
# x trec06c/data/049/240
# x trec06c/data/049/069
# x trec06c/data/049/221
# x trec06c/data/049/021
# x trec06c/data/049/125
# x trec06c/data/049/191
# x trec06c/data/049/087
# x trec06c/data/049/118
# x trec06c/data/049/119
# x trec06c/data/049/011
# x trec06c/data/049/071
# x trec06c/data/049/014
# x trec06c/data/049/082
# x trec06c/data/049/076
# x trec06c/data/049/150
# x trec06c/data/049/211
# x trec06c/data/049/059
# x trec06c/data/049/029
# x trec06c/data/049/173
# x trec06c/data/049/010
# x trec06c/data/049/148
# x trec06c/data/049/256
# x trec06c/data/049/172
# x trec06c/data/049/124
# x trec06c/data/049/296
# x trec06c/data/049/234
# x trec06c/data/049/167
# x trec06c/data/049/079
# x trec06c/data/049/227
# x trec06c/data/049/078
# x trec06c/data/049/277
# x trec06c/data/049/126
# x trec06c/data/049/185
# x trec06c/data/049/108
# x trec06c/data/049/290
# x trec06c/data/049/228
# x trec06c/data/049/246
# x trec06c/data/049/200
# x trec06c/data/049/284
# x trec06c/data/049/056
# x trec06c/data/049/212
# x trec06c/data/049/292
# x trec06c/data/049/116
# x trec06c/data/049/095
# x trec06c/data/049/127
# x trec06c/data/049/007
# x trec06c/data/049/052
# x trec06c/data/049/156
# x trec06c/data/049/083
# x trec06c/data/049/088
# x trec06c/data/049/084
# x trec06c/data/049/115
# x trec06c/data/049/157
# x trec06c/data/049/130
# x trec06c/data/049/281
# x trec06c/data/049/081
# x trec06c/data/049/206
# x trec06c/data/049/261
# x trec06c/data/049/264
# x trec06c/data/049/110
# x trec06c/data/049/213
# x trec06c/data/049/280
# x trec06c/data/049/070
# x trec06c/data/049/030
# x trec06c/data/049/045
# x trec06c/data/049/141
# x trec06c/data/049/147
# x trec06c/data/049/289
# x trec06c/data/049/135
# x trec06c/data/049/112
# x trec06c/data/049/276
# x trec06c/data/049/048
# x trec06c/data/049/091
# x trec06c/data/049/047
# x trec06c/data/049/096
# x trec06c/data/049/040
# x trec06c/data/049/107
# x trec06c/data/049/232
# x trec06c/data/049/002
# x trec06c/data/049/017
# x trec06c/data/049/209
# x trec06c/data/049/249
# x trec06c/data/049/283
# x trec06c/data/049/137
# x trec06c/data/049/164
# x trec06c/data/049/275
# x trec06c/data/049/196
# x trec06c/data/049/121
# x trec06c/data/049/120
# x trec06c/data/049/063
# x trec06c/data/049/193
# x trec06c/data/049/201
# x trec06c/data/049/239
# x trec06c/data/049/287
# x trec06c/data/049/025
# x trec06c/data/049/020
# x trec06c/data/049/229
# x trec06c/data/049/205
# x trec06c/data/049/242
# x trec06c/data/049/171
# x trec06c/data/049/019
# x trec06c/data/049/128
# x trec06c/data/049/042
# x trec06c/data/049/142
# x trec06c/data/049/208
# x trec06c/data/049/074
# x trec06c/data/049/178
# x trec06c/data/049/250
# x trec06c/data/049/133
# x trec06c/data/049/223
# x trec06c/data/049/166
# x trec06c/data/049/266
# x trec06c/data/049/132
# x trec06c/data/049/163
# x trec06c/data/175/
# x trec06c/data/175/252
# x trec06c/data/175/260
# x trec06c/data/175/101
# x trec06c/data/175/254
# x trec06c/data/175/262
# x trec06c/data/175/279
# x trec06c/data/175/037
# x trec06c/data/175/278
# x trec06c/data/175/186
# x trec06c/data/175/140
# x trec06c/data/175/049
# x trec06c/data/175/175
# x trec06c/data/175/093
# x trec06c/data/175/024
# x trec06c/data/175/230
# x trec06c/data/175/159
# x trec06c/data/175/160
# x trec06c/data/175/051
# x trec06c/data/175/184
# x trec06c/data/175/293
# x trec06c/data/175/238
# x trec06c/data/175/222
# x trec06c/data/175/044
# x trec06c/data/175/235
# x trec06c/data/175/183
# x trec06c/data/175/255
# x trec06c/data/175/152
# x trec06c/data/175/034
# x trec06c/data/175/216
# x trec06c/data/175/270
# x trec06c/data/175/109
# x trec06c/data/175/210
# x trec06c/data/175/054
# x trec06c/data/175/111
# x trec06c/data/175/149
# x trec06c/data/175/258
# x trec06c/data/175/032
# x trec06c/data/175/151
# x trec06c/data/175/023
# x trec06c/data/175/158
# x trec06c/data/175/143
# x trec06c/data/175/105
# x trec06c/data/175/122
# x trec06c/data/175/247
# x trec06c/data/175/009
# x trec06c/data/175/013
# x trec06c/data/175/104
# x trec06c/data/175/294
# x trec06c/data/175/144
# x trec06c/data/175/263
# x trec06c/data/175/145
# x trec06c/data/175/134
# x trec06c/data/175/098
# x trec06c/data/175/236
# x trec06c/data/175/046
# x trec06c/data/175/131
# x trec06c/data/175/006
# x trec06c/data/175/161
# x trec06c/data/175/198
# x trec06c/data/175/299
# x trec06c/data/175/138
# x trec06c/data/175/089
# x trec06c/data/175/187
# x trec06c/data/175/094
# x trec06c/data/175/179
# x trec06c/data/175/092
# x trec06c/data/175/033
# x trec06c/data/175/001
# x trec06c/data/175/267
# x trec06c/data/175/244
# x trec06c/data/175/225
# x trec06c/data/175/197
# x trec06c/data/175/085
# x trec06c/data/175/066
# x trec06c/data/175/077
# x trec06c/data/175/139
# x trec06c/data/175/058
# x trec06c/data/175/285
# x trec06c/data/175/251
# x trec06c/data/175/195
# x trec06c/data/175/015
# x trec06c/data/175/035
# x trec06c/data/175/154
# x trec06c/data/175/190
# x trec06c/data/175/067
# x trec06c/data/175/180
# x trec06c/data/175/272
# x trec06c/data/175/062
# x trec06c/data/175/155
# x trec06c/data/175/245
# x trec06c/data/175/061
# x trec06c/data/175/099
# x trec06c/data/175/199
# x trec06c/data/175/217
# x trec06c/data/175/295
# x trec06c/data/175/057
# x trec06c/data/175/291
# x trec06c/data/175/027
# x trec06c/data/175/215
# x trec06c/data/175/174
# x trec06c/data/175/028
# x trec06c/data/175/188
# x trec06c/data/175/194
# x trec06c/data/175/271
# x trec06c/data/175/038
# x trec06c/data/175/257
# x trec06c/data/175/202
# x trec06c/data/175/182
# x trec06c/data/175/298
# x trec06c/data/175/000
# x trec06c/data/175/053
# x trec06c/data/175/018
# x trec06c/data/175/102
# x trec06c/data/175/176
# x trec06c/data/175/203
# x trec06c/data/175/204
# x trec06c/data/175/219
# x trec06c/data/175/259
# x trec06c/data/175/243
# x trec06c/data/175/103
# x trec06c/data/175/265
# x trec06c/data/175/113
# x trec06c/data/175/282
# x trec06c/data/175/226
# x trec06c/data/175/168
# x trec06c/data/175/224
# x trec06c/data/175/207
# x trec06c/data/175/165
# x trec06c/data/175/136
# x trec06c/data/175/003
# x trec06c/data/175/065
# x trec06c/data/175/041
# x trec06c/data/175/189
# x trec06c/data/175/162
# x trec06c/data/175/068
# x trec06c/data/175/100
# x trec06c/data/175/005
# x trec06c/data/175/286
# x trec06c/data/175/181
# x trec06c/data/175/072
# x trec06c/data/175/129
# x trec06c/data/175/114
# x trec06c/data/175/248
# x trec06c/data/175/214
# x trec06c/data/175/268
# x trec06c/data/175/177
# x trec06c/data/175/090
# x trec06c/data/175/218
# x trec06c/data/175/008
# x trec06c/data/175/220
# x trec06c/data/175/237
# x trec06c/data/175/170
# x trec06c/data/175/106
# x trec06c/data/175/043
# x trec06c/data/175/080
# x trec06c/data/175/064
# x trec06c/data/175/055
# x trec06c/data/175/273
# x trec06c/data/175/004
# x trec06c/data/175/039
# x trec06c/data/175/036
# x trec06c/data/175/031
# x trec06c/data/175/169
# x trec06c/data/175/097
# x trec06c/data/175/022
# x trec06c/data/175/153
# x trec06c/data/175/297
# x trec06c/data/175/269
# x trec06c/data/175/050
# x trec06c/data/175/288
# x trec06c/data/175/075
# x trec06c/data/175/274
# x trec06c/data/175/073
# x trec06c/data/175/060
# x trec06c/data/175/192
# x trec06c/data/175/241
# x trec06c/data/175/026
# x trec06c/data/175/123
# x trec06c/data/175/233
# x trec06c/data/175/086
# x trec06c/data/175/012
# x trec06c/data/175/231
# x trec06c/data/175/117
# x trec06c/data/175/253
# x trec06c/data/175/146
# x trec06c/data/175/016
# x trec06c/data/175/240
# x trec06c/data/175/069
# x trec06c/data/175/221
# x trec06c/data/175/021
# x trec06c/data/175/125
# x trec06c/data/175/191
# x trec06c/data/175/087
# x trec06c/data/175/118
# x trec06c/data/175/119
# x trec06c/data/175/011
# x trec06c/data/175/071
# x trec06c/data/175/014
# x trec06c/data/175/082
# x trec06c/data/175/076
# x trec06c/data/175/150
# x trec06c/data/175/211
# x trec06c/data/175/059
# x trec06c/data/175/029
# x trec06c/data/175/173
# x trec06c/data/175/010
# x trec06c/data/175/148
# x trec06c/data/175/256
# x trec06c/data/175/172
# x trec06c/data/175/124
# x trec06c/data/175/296
# x trec06c/data/175/234
# x trec06c/data/175/167
# x trec06c/data/175/079
# x trec06c/data/175/227
# x trec06c/data/175/078
# x trec06c/data/175/277
# x trec06c/data/175/126
# x trec06c/data/175/185
# x trec06c/data/175/108
# x trec06c/data/175/290
# x trec06c/data/175/228
# x trec06c/data/175/246
# x trec06c/data/175/200
# x trec06c/data/175/284
# x trec06c/data/175/056
# x trec06c/data/175/212
# x trec06c/data/175/292
# x trec06c/data/175/116
# x trec06c/data/175/095
# x trec06c/data/175/127
# x trec06c/data/175/007
# x trec06c/data/175/052
# x trec06c/data/175/156
# x trec06c/data/175/083
# x trec06c/data/175/088
# x trec06c/data/175/084
# x trec06c/data/175/115
# x trec06c/data/175/157
# x trec06c/data/175/130
# x trec06c/data/175/281
# x trec06c/data/175/081
# x trec06c/data/175/206
# x trec06c/data/175/261
# x trec06c/data/175/264
# x trec06c/data/175/110
# x trec06c/data/175/213
# x trec06c/data/175/280
# x trec06c/data/175/070
# x trec06c/data/175/030
# x trec06c/data/175/045
# x trec06c/data/175/141
# x trec06c/data/175/147
# x trec06c/data/175/289
# x trec06c/data/175/135
# x trec06c/data/175/112
# x trec06c/data/175/276
# x trec06c/data/175/048
# x trec06c/data/175/091
# x trec06c/data/175/047
# x trec06c/data/175/096
# x trec06c/data/175/040
# x trec06c/data/175/107
# x trec06c/data/175/232
# x trec06c/data/175/002
# x trec06c/data/175/017
# x trec06c/data/175/209
# x trec06c/data/175/249
# x trec06c/data/175/283
# x trec06c/data/175/137
# x trec06c/data/175/164
# x trec06c/data/175/275
# x trec06c/data/175/196
# x trec06c/data/175/121
# x trec06c/data/175/120
# x trec06c/data/175/063
# x trec06c/data/175/193
# x trec06c/data/175/201
# x trec06c/data/175/239
# x trec06c/data/175/287
# x trec06c/data/175/025
# x trec06c/data/175/020
# x trec06c/data/175/229
# x trec06c/data/175/205
# x trec06c/data/175/242
# x trec06c/data/175/171
# x trec06c/data/175/019
# x trec06c/data/175/128
# x trec06c/data/175/042
# x trec06c/data/175/142
# x trec06c/data/175/208
# x trec06c/data/175/074
# x trec06c/data/175/178
# x trec06c/data/175/250
# x trec06c/data/175/133
# x trec06c/data/175/223
# x trec06c/data/175/166
# x trec06c/data/175/266
# x trec06c/data/175/132
# x trec06c/data/175/163
# x trec06c/data/093/
# x trec06c/data/093/252
# x trec06c/data/093/260
# x trec06c/data/093/101
# x trec06c/data/093/254
# x trec06c/data/093/262
# x trec06c/data/093/279
# x trec06c/data/093/037
# x trec06c/data/093/278
# x trec06c/data/093/186
# x trec06c/data/093/140
# x trec06c/data/093/049
# x trec06c/data/093/175
# x trec06c/data/093/093
# x trec06c/data/093/024
# x trec06c/data/093/230
# x trec06c/data/093/159
# x trec06c/data/093/160
# x trec06c/data/093/051
# x trec06c/data/093/184
# x trec06c/data/093/293
# x trec06c/data/093/238
# x trec06c/data/093/222
# x trec06c/data/093/044
# x trec06c/data/093/235
# x trec06c/data/093/183
# x trec06c/data/093/255
# x trec06c/data/093/152
# x trec06c/data/093/034
# x trec06c/data/093/216
# x trec06c/data/093/270
# x trec06c/data/093/109
# x trec06c/data/093/210
# x trec06c/data/093/054
# x trec06c/data/093/111
# x trec06c/data/093/149
# x trec06c/data/093/258
# x trec06c/data/093/032
# x trec06c/data/093/151
# x trec06c/data/093/023
# x trec06c/data/093/158
# x trec06c/data/093/143
# x trec06c/data/093/105
# x trec06c/data/093/122
# x trec06c/data/093/247
# x trec06c/data/093/009
# x trec06c/data/093/013
# x trec06c/data/093/104
# x trec06c/data/093/294
# x trec06c/data/093/144
# x trec06c/data/093/263
# x trec06c/data/093/145
# x trec06c/data/093/134
# x trec06c/data/093/098
# x trec06c/data/093/236
# x trec06c/data/093/046
# x trec06c/data/093/131
# x trec06c/data/093/006
# x trec06c/data/093/161
# x trec06c/data/093/198
# x trec06c/data/093/299
# x trec06c/data/093/138
# x trec06c/data/093/089
# x trec06c/data/093/187
# x trec06c/data/093/094
# x trec06c/data/093/179
# x trec06c/data/093/092
# x trec06c/data/093/033
# x trec06c/data/093/001
# x trec06c/data/093/267
# x trec06c/data/093/244
# x trec06c/data/093/225
# x trec06c/data/093/197
# x trec06c/data/093/085
# x trec06c/data/093/066
# x trec06c/data/093/077
# x trec06c/data/093/139
# x trec06c/data/093/058
# x trec06c/data/093/285
# x trec06c/data/093/251
# x trec06c/data/093/195
# x trec06c/data/093/015
# x trec06c/data/093/035
# x trec06c/data/093/154
# x trec06c/data/093/190
# x trec06c/data/093/067
# x trec06c/data/093/180
# x trec06c/data/093/272
# x trec06c/data/093/062
# x trec06c/data/093/155
# x trec06c/data/093/245
# x trec06c/data/093/061
# x trec06c/data/093/099
# x trec06c/data/093/199
# x trec06c/data/093/217
# x trec06c/data/093/295
# x trec06c/data/093/057
# x trec06c/data/093/291
# x trec06c/data/093/027
# x trec06c/data/093/215
# x trec06c/data/093/174
# x trec06c/data/093/028
# x trec06c/data/093/188
# x trec06c/data/093/194
# x trec06c/data/093/271
# x trec06c/data/093/038
# x trec06c/data/093/257
# x trec06c/data/093/202
# x trec06c/data/093/182
# x trec06c/data/093/298
# x trec06c/data/093/000
# x trec06c/data/093/053
# x trec06c/data/093/018
# x trec06c/data/093/102
# x trec06c/data/093/176
# x trec06c/data/093/203
# x trec06c/data/093/204
# x trec06c/data/093/219
# x trec06c/data/093/259
# x trec06c/data/093/243
# x trec06c/data/093/103
# x trec06c/data/093/265
# x trec06c/data/093/113
# x trec06c/data/093/282
# x trec06c/data/093/226
# x trec06c/data/093/168
# x trec06c/data/093/224
# x trec06c/data/093/207
# x trec06c/data/093/165
# x trec06c/data/093/136
# x trec06c/data/093/003
# x trec06c/data/093/065
# x trec06c/data/093/041
# x trec06c/data/093/189
# x trec06c/data/093/162
# x trec06c/data/093/068
# x trec06c/data/093/100
# x trec06c/data/093/005
# x trec06c/data/093/286
# x trec06c/data/093/181
# x trec06c/data/093/072
# x trec06c/data/093/129
# x trec06c/data/093/114
# x trec06c/data/093/248
# x trec06c/data/093/214
# x trec06c/data/093/268
# x trec06c/data/093/177
# x trec06c/data/093/090
# x trec06c/data/093/218
# x trec06c/data/093/008
# x trec06c/data/093/220
# x trec06c/data/093/237
# x trec06c/data/093/170
# x trec06c/data/093/106
# x trec06c/data/093/043
# x trec06c/data/093/080
# x trec06c/data/093/064
# x trec06c/data/093/055
# x trec06c/data/093/273
# x trec06c/data/093/004
# x trec06c/data/093/039
# x trec06c/data/093/036
# x trec06c/data/093/031
# x trec06c/data/093/169
# x trec06c/data/093/097
# x trec06c/data/093/022
# x trec06c/data/093/153
# x trec06c/data/093/297
# x trec06c/data/093/269
# x trec06c/data/093/050
# x trec06c/data/093/288
# x trec06c/data/093/075
# x trec06c/data/093/274
# x trec06c/data/093/073
# x trec06c/data/093/060
# x trec06c/data/093/192
# x trec06c/data/093/241
# x trec06c/data/093/026
# x trec06c/data/093/123
# x trec06c/data/093/233
# x trec06c/data/093/086
# x trec06c/data/093/012
# x trec06c/data/093/231
# x trec06c/data/093/117
# x trec06c/data/093/253
# x trec06c/data/093/146
# x trec06c/data/093/016
# x trec06c/data/093/240
# x trec06c/data/093/069
# x trec06c/data/093/221
# x trec06c/data/093/021
# x trec06c/data/093/125
# x trec06c/data/093/191
# x trec06c/data/093/087
# x trec06c/data/093/118
# x trec06c/data/093/119
# x trec06c/data/093/011
# x trec06c/data/093/071
# x trec06c/data/093/014
# x trec06c/data/093/082
# x trec06c/data/093/076
# x trec06c/data/093/150
# x trec06c/data/093/211
# x trec06c/data/093/059
# x trec06c/data/093/029
# x trec06c/data/093/173
# x trec06c/data/093/010
# x trec06c/data/093/148
# x trec06c/data/093/256
# x trec06c/data/093/172
# x trec06c/data/093/124
# x trec06c/data/093/296
# x trec06c/data/093/234
# x trec06c/data/093/167
# x trec06c/data/093/079
# x trec06c/data/093/227
# x trec06c/data/093/078
# x trec06c/data/093/277
# x trec06c/data/093/126
# x trec06c/data/093/185
# x trec06c/data/093/108
# x trec06c/data/093/290
# x trec06c/data/093/228
# x trec06c/data/093/246
# x trec06c/data/093/200
# x trec06c/data/093/284
# x trec06c/data/093/056
# x trec06c/data/093/212
# x trec06c/data/093/292
# x trec06c/data/093/116
# x trec06c/data/093/095
# x trec06c/data/093/127
# x trec06c/data/093/007
# x trec06c/data/093/052
# x trec06c/data/093/156
# x trec06c/data/093/083
# x trec06c/data/093/088
# x trec06c/data/093/084
# x trec06c/data/093/115
# x trec06c/data/093/157
# x trec06c/data/093/130
# x trec06c/data/093/281
# x trec06c/data/093/081
# x trec06c/data/093/206
# x trec06c/data/093/261
# x trec06c/data/093/264
# x trec06c/data/093/110
# x trec06c/data/093/213
# x trec06c/data/093/280
# x trec06c/data/093/070
# x trec06c/data/093/030
# x trec06c/data/093/045
# x trec06c/data/093/141
# x trec06c/data/093/147
# x trec06c/data/093/289
# x trec06c/data/093/135
# x trec06c/data/093/112
# x trec06c/data/093/276
# x trec06c/data/093/048
# x trec06c/data/093/091
# x trec06c/data/093/047
# x trec06c/data/093/096
# x trec06c/data/093/040
# x trec06c/data/093/107
# x trec06c/data/093/232
# x trec06c/data/093/002
# x trec06c/data/093/017
# x trec06c/data/093/209
# x trec06c/data/093/249
# x trec06c/data/093/283
# x trec06c/data/093/137
# x trec06c/data/093/164
# x trec06c/data/093/275
# x trec06c/data/093/196
# x trec06c/data/093/121
# x trec06c/data/093/120
# x trec06c/data/093/063
# x trec06c/data/093/193
# x trec06c/data/093/201
# x trec06c/data/093/239
# ...
# x trec06c/data/166/296
# x trec06c/data/166/234
# x trec06c/data/166/167
# x trec06c/data/166/079
# x trec06c/data/166/227
# x trec06c/data/166/078
# x trec06c/data/166/277
# x trec06c/data/166/126
# x trec06c/data/166/185
# x trec06c/data/166/108
# x trec06c/data/166/290
# x trec06c/data/166/228
# x trec06c/data/166/246
# x trec06c/data/166/200
# x trec06c/data/166/284
# x trec06c/data/166/056
# x trec06c/data/166/212
# x trec06c/data/166/292
# x trec06c/data/166/116
# x trec06c/data/166/095
# x trec06c/data/166/127
# x trec06c/data/166/007
# x trec06c/data/166/052
# x trec06c/data/166/156
# x trec06c/data/166/083
# x trec06c/data/166/088
# x trec06c/data/166/084
# x trec06c/data/166/115
# x trec06c/data/166/157
# x trec06c/data/166/130
# x trec06c/data/166/281
# x trec06c/data/166/081
# x trec06c/data/166/206
# x trec06c/data/166/261
# x trec06c/data/166/264
# x trec06c/data/166/110
# x trec06c/data/166/213
# x trec06c/data/166/280
# x trec06c/data/166/070
# x trec06c/data/166/030
# x trec06c/data/166/045
# x trec06c/data/166/141
# x trec06c/data/166/147
# x trec06c/data/166/289
# x trec06c/data/166/135
# x trec06c/data/166/112
# x trec06c/data/166/276
# x trec06c/data/166/048
# x trec06c/data/166/091
# x trec06c/data/166/047
# x trec06c/data/166/096
# x trec06c/data/166/040
# x trec06c/data/166/107
# x trec06c/data/166/232
# x trec06c/data/166/002
# x trec06c/data/166/017
# x trec06c/data/166/209
# x trec06c/data/166/249
# x trec06c/data/166/283
# x trec06c/data/166/137
# x trec06c/data/166/164
# x trec06c/data/166/275
# x trec06c/data/166/196
# x trec06c/data/166/121
# x trec06c/data/166/120
# x trec06c/data/166/063
# x trec06c/data/166/193
# x trec06c/data/166/201
# x trec06c/data/166/239
# x trec06c/data/166/287
# x trec06c/data/166/025
# x trec06c/data/166/020
# x trec06c/data/166/229
# x trec06c/data/166/205
# x trec06c/data/166/242
# x trec06c/data/166/171
# x trec06c/data/166/019
# x trec06c/data/166/128
# x trec06c/data/166/042
# x trec06c/data/166/142
# x trec06c/data/166/208
# x trec06c/data/166/074
# x trec06c/data/166/178
# x trec06c/data/166/250
# x trec06c/data/166/133
# x trec06c/data/166/223
# x trec06c/data/166/166
# x trec06c/data/166/266
# x trec06c/data/166/132
# x trec06c/data/166/163
# x trec06c/data/132/
# x trec06c/data/132/252
# x trec06c/data/132/260
# x trec06c/data/132/101
# x trec06c/data/132/254
# x trec06c/data/132/262
# x trec06c/data/132/279
# x trec06c/data/132/037
# x trec06c/data/132/278
# x trec06c/data/132/186
# x trec06c/data/132/140
# x trec06c/data/132/049
# x trec06c/data/132/175
# x trec06c/data/132/093
# x trec06c/data/132/024
# x trec06c/data/132/230
# x trec06c/data/132/159
# x trec06c/data/132/160
# x trec06c/data/132/051
# x trec06c/data/132/184
# x trec06c/data/132/293
# x trec06c/data/132/238
# x trec06c/data/132/222
# x trec06c/data/132/044
# x trec06c/data/132/235
# x trec06c/data/132/183
# x trec06c/data/132/255
# x trec06c/data/132/152
# x trec06c/data/132/034
# x trec06c/data/132/216
# x trec06c/data/132/270
# x trec06c/data/132/109
# x trec06c/data/132/210
# x trec06c/data/132/054
# x trec06c/data/132/111
# x trec06c/data/132/149
# x trec06c/data/132/258
# x trec06c/data/132/032
# x trec06c/data/132/151
# x trec06c/data/132/023
# x trec06c/data/132/158
# x trec06c/data/132/143
# x trec06c/data/132/105
# x trec06c/data/132/122
# x trec06c/data/132/247
# x trec06c/data/132/009
# x trec06c/data/132/013
# x trec06c/data/132/104
# x trec06c/data/132/294
# x trec06c/data/132/144
# x trec06c/data/132/263
# x trec06c/data/132/145
# x trec06c/data/132/134
# x trec06c/data/132/098
# x trec06c/data/132/236
# x trec06c/data/132/046
# x trec06c/data/132/131
# x trec06c/data/132/006
# x trec06c/data/132/161
# x trec06c/data/132/198
# x trec06c/data/132/299
# x trec06c/data/132/138
# x trec06c/data/132/089
# x trec06c/data/132/187
# x trec06c/data/132/094
# x trec06c/data/132/179
# x trec06c/data/132/092
# x trec06c/data/132/033
# x trec06c/data/132/001
# x trec06c/data/132/267
# x trec06c/data/132/244
# x trec06c/data/132/225
# x trec06c/data/132/197
# x trec06c/data/132/085
# x trec06c/data/132/066
# x trec06c/data/132/077
# x trec06c/data/132/139
# x trec06c/data/132/058
# x trec06c/data/132/285
# x trec06c/data/132/251
# x trec06c/data/132/195
# x trec06c/data/132/015
# x trec06c/data/132/035
# x trec06c/data/132/154
# x trec06c/data/132/190
# x trec06c/data/132/067
# x trec06c/data/132/180
# x trec06c/data/132/272
# x trec06c/data/132/062
# x trec06c/data/132/155
# x trec06c/data/132/245
# x trec06c/data/132/061
# x trec06c/data/132/099
# x trec06c/data/132/199
# x trec06c/data/132/217
# x trec06c/data/132/295
# x trec06c/data/132/057
# x trec06c/data/132/291
# x trec06c/data/132/027
# x trec06c/data/132/215
# x trec06c/data/132/174
# x trec06c/data/132/028
# x trec06c/data/132/188
# x trec06c/data/132/194
# x trec06c/data/132/271
# x trec06c/data/132/038
# x trec06c/data/132/257
# x trec06c/data/132/202
# x trec06c/data/132/182
# x trec06c/data/132/298
# x trec06c/data/132/000
# x trec06c/data/132/053
# x trec06c/data/132/018
# x trec06c/data/132/102
# x trec06c/data/132/176
# x trec06c/data/132/203
# x trec06c/data/132/204
# x trec06c/data/132/219
# x trec06c/data/132/259
# x trec06c/data/132/243
# x trec06c/data/132/103
# x trec06c/data/132/265
# x trec06c/data/132/113
# x trec06c/data/132/282
# x trec06c/data/132/226
# x trec06c/data/132/168
# x trec06c/data/132/224
# x trec06c/data/132/207
# x trec06c/data/132/165
# x trec06c/data/132/136
# x trec06c/data/132/003
# x trec06c/data/132/065
# x trec06c/data/132/041
# x trec06c/data/132/189
# x trec06c/data/132/162
# x trec06c/data/132/068
# x trec06c/data/132/100
# x trec06c/data/132/005
# x trec06c/data/132/286
# x trec06c/data/132/181
# x trec06c/data/132/072
# x trec06c/data/132/129
# x trec06c/data/132/114
# x trec06c/data/132/248
# x trec06c/data/132/214
# x trec06c/data/132/268
# x trec06c/data/132/177
# x trec06c/data/132/090
# x trec06c/data/132/218
# x trec06c/data/132/008
# x trec06c/data/132/220
# x trec06c/data/132/237
# x trec06c/data/132/170
# x trec06c/data/132/106
# x trec06c/data/132/043
# x trec06c/data/132/080
# x trec06c/data/132/064
# x trec06c/data/132/055
# x trec06c/data/132/273
# x trec06c/data/132/004
# x trec06c/data/132/039
# x trec06c/data/132/036
# x trec06c/data/132/031
# x trec06c/data/132/169
# x trec06c/data/132/097
# x trec06c/data/132/022
# x trec06c/data/132/153
# x trec06c/data/132/297
# x trec06c/data/132/269
# x trec06c/data/132/050
# x trec06c/data/132/288
# x trec06c/data/132/075
# x trec06c/data/132/274
# x trec06c/data/132/073
# x trec06c/data/132/060
# x trec06c/data/132/192
# x trec06c/data/132/241
# x trec06c/data/132/026
# x trec06c/data/132/123
# x trec06c/data/132/233
# x trec06c/data/132/086
# x trec06c/data/132/012
# x trec06c/data/132/231
# x trec06c/data/132/117
# x trec06c/data/132/253
# x trec06c/data/132/146
# x trec06c/data/132/016
# x trec06c/data/132/240
# x trec06c/data/132/069
# x trec06c/data/132/221
# x trec06c/data/132/021
# x trec06c/data/132/125
# x trec06c/data/132/191
# x trec06c/data/132/087
# x trec06c/data/132/118
# x trec06c/data/132/119
# x trec06c/data/132/011
# x trec06c/data/132/071
# x trec06c/data/132/014
# x trec06c/data/132/082
# x trec06c/data/132/076
# x trec06c/data/132/150
# x trec06c/data/132/211
# x trec06c/data/132/059
# x trec06c/data/132/029
# x trec06c/data/132/173
# x trec06c/data/132/010
# x trec06c/data/132/148
# x trec06c/data/132/256
# x trec06c/data/132/172
# x trec06c/data/132/124
# x trec06c/data/132/296
# x trec06c/data/132/234
# x trec06c/data/132/167
# x trec06c/data/132/079
# x trec06c/data/132/227
# x trec06c/data/132/078
# x trec06c/data/132/277
# x trec06c/data/132/126
# x trec06c/data/132/185
# x trec06c/data/132/108
# x trec06c/data/132/290
# x trec06c/data/132/228
# x trec06c/data/132/246
# x trec06c/data/132/200
# x trec06c/data/132/284
# x trec06c/data/132/056
# x trec06c/data/132/212
# x trec06c/data/132/292
# x trec06c/data/132/116
# x trec06c/data/132/095
# x trec06c/data/132/127
# x trec06c/data/132/007
# x trec06c/data/132/052
# x trec06c/data/132/156
# x trec06c/data/132/083
# x trec06c/data/132/088
# x trec06c/data/132/084
# x trec06c/data/132/115
# x trec06c/data/132/157
# x trec06c/data/132/130
# x trec06c/data/132/281
# x trec06c/data/132/081
# x trec06c/data/132/206
# x trec06c/data/132/261
# x trec06c/data/132/264
# x trec06c/data/132/110
# x trec06c/data/132/213
# x trec06c/data/132/280
# x trec06c/data/132/070
# x trec06c/data/132/030
# x trec06c/data/132/045
# x trec06c/data/132/141
# x trec06c/data/132/147
# x trec06c/data/132/289
# x trec06c/data/132/135
# x trec06c/data/132/112
# x trec06c/data/132/276
# x trec06c/data/132/048
# x trec06c/data/132/091
# x trec06c/data/132/047
# x trec06c/data/132/096
# x trec06c/data/132/040
# x trec06c/data/132/107
# x trec06c/data/132/232
# x trec06c/data/132/002
# x trec06c/data/132/017
# x trec06c/data/132/209
# x trec06c/data/132/249
# x trec06c/data/132/283
# x trec06c/data/132/137
# x trec06c/data/132/164
# x trec06c/data/132/275
# x trec06c/data/132/196
# x trec06c/data/132/121
# x trec06c/data/132/120
# x trec06c/data/132/063
# x trec06c/data/132/193
# x trec06c/data/132/201
# x trec06c/data/132/239
# x trec06c/data/132/287
# x trec06c/data/132/025
# x trec06c/data/132/020
# x trec06c/data/132/229
# x trec06c/data/132/205
# x trec06c/data/132/242
# x trec06c/data/132/171
# x trec06c/data/132/019
# x trec06c/data/132/128
# x trec06c/data/132/042
# x trec06c/data/132/142
# x trec06c/data/132/208
# x trec06c/data/132/074
# x trec06c/data/132/178
# x trec06c/data/132/250
# x trec06c/data/132/133
# x trec06c/data/132/223
# x trec06c/data/132/166
# x trec06c/data/132/266
# x trec06c/data/132/132
# x trec06c/data/132/163
# x trec06c/data/163/
# x trec06c/data/163/252
# x trec06c/data/163/260
# x trec06c/data/163/101
# x trec06c/data/163/254
# x trec06c/data/163/262
# x trec06c/data/163/279
# x trec06c/data/163/037
# x trec06c/data/163/278
# x trec06c/data/163/186
# x trec06c/data/163/140
# x trec06c/data/163/049
# x trec06c/data/163/175
# x trec06c/data/163/093
# x trec06c/data/163/024
# x trec06c/data/163/230
# x trec06c/data/163/159
# x trec06c/data/163/160
# x trec06c/data/163/051
# x trec06c/data/163/184
# x trec06c/data/163/293
# x trec06c/data/163/238
# x trec06c/data/163/222
# x trec06c/data/163/044
# x trec06c/data/163/235
# x trec06c/data/163/183
# x trec06c/data/163/255
# x trec06c/data/163/152
# x trec06c/data/163/034
# x trec06c/data/163/216
# x trec06c/data/163/270
# x trec06c/data/163/109
# x trec06c/data/163/210
# x trec06c/data/163/054
# x trec06c/data/163/111
# x trec06c/data/163/149
# x trec06c/data/163/258
# x trec06c/data/163/032
# x trec06c/data/163/151
# x trec06c/data/163/023
# x trec06c/data/163/158
# x trec06c/data/163/143
# x trec06c/data/163/105
# x trec06c/data/163/122
# x trec06c/data/163/247
# x trec06c/data/163/009
# x trec06c/data/163/013
# x trec06c/data/163/104
# x trec06c/data/163/294
# x trec06c/data/163/144
# x trec06c/data/163/263
# x trec06c/data/163/145
# x trec06c/data/163/134
# x trec06c/data/163/098
# x trec06c/data/163/236
# x trec06c/data/163/046
# x trec06c/data/163/131
# x trec06c/data/163/006
# x trec06c/data/163/161
# x trec06c/data/163/198
# x trec06c/data/163/299
# x trec06c/data/163/138
# x trec06c/data/163/089
# x trec06c/data/163/187
# x trec06c/data/163/094
# x trec06c/data/163/179
# x trec06c/data/163/092
# x trec06c/data/163/033
# x trec06c/data/163/001
# x trec06c/data/163/267
# x trec06c/data/163/244
# x trec06c/data/163/225
# x trec06c/data/163/197
# x trec06c/data/163/085
# x trec06c/data/163/066
# x trec06c/data/163/077
# x trec06c/data/163/139
# x trec06c/data/163/058
# x trec06c/data/163/285
# x trec06c/data/163/251
# x trec06c/data/163/195
# x trec06c/data/163/015
# x trec06c/data/163/035
# x trec06c/data/163/154
# x trec06c/data/163/190
# x trec06c/data/163/067
# x trec06c/data/163/180
# x trec06c/data/163/272
# x trec06c/data/163/062
# x trec06c/data/163/155
# x trec06c/data/163/245
# x trec06c/data/163/061
# x trec06c/data/163/099
# x trec06c/data/163/199
# x trec06c/data/163/217
# x trec06c/data/163/295
# x trec06c/data/163/057
# x trec06c/data/163/291
# x trec06c/data/163/027
# x trec06c/data/163/215
# x trec06c/data/163/174
# x trec06c/data/163/028
# x trec06c/data/163/188
# x trec06c/data/163/194
# x trec06c/data/163/271
# x trec06c/data/163/038
# x trec06c/data/163/257
# x trec06c/data/163/202
# x trec06c/data/163/182
# x trec06c/data/163/298
# x trec06c/data/163/000
# x trec06c/data/163/053
# x trec06c/data/163/018
# x trec06c/data/163/102
# x trec06c/data/163/176
# x trec06c/data/163/203
# x trec06c/data/163/204
# x trec06c/data/163/219
# x trec06c/data/163/259
# x trec06c/data/163/243
# x trec06c/data/163/103
# x trec06c/data/163/265
# x trec06c/data/163/113
# x trec06c/data/163/282
# x trec06c/data/163/226
# x trec06c/data/163/168
# x trec06c/data/163/224
# x trec06c/data/163/207
# x trec06c/data/163/165
# x trec06c/data/163/136
# x trec06c/data/163/003
# x trec06c/data/163/065
# x trec06c/data/163/041
# x trec06c/data/163/189
# x trec06c/data/163/162
# x trec06c/data/163/068
# x trec06c/data/163/100
# x trec06c/data/163/005
# x trec06c/data/163/286
# x trec06c/data/163/181
# x trec06c/data/163/072
# x trec06c/data/163/129
# x trec06c/data/163/114
# x trec06c/data/163/248
# x trec06c/data/163/214
# x trec06c/data/163/268
# x trec06c/data/163/177
# x trec06c/data/163/090
# x trec06c/data/163/218
# x trec06c/data/163/008
# x trec06c/data/163/220
# x trec06c/data/163/237
# x trec06c/data/163/170
# x trec06c/data/163/106
# x trec06c/data/163/043
# x trec06c/data/163/080
# x trec06c/data/163/064
# x trec06c/data/163/055
# x trec06c/data/163/273
# x trec06c/data/163/004
# x trec06c/data/163/039
# x trec06c/data/163/036
# x trec06c/data/163/031
# x trec06c/data/163/169
# x trec06c/data/163/097
# x trec06c/data/163/022
# x trec06c/data/163/153
# x trec06c/data/163/297
# x trec06c/data/163/269
# x trec06c/data/163/050
# x trec06c/data/163/288
# x trec06c/data/163/075
# x trec06c/data/163/274
# x trec06c/data/163/073
# x trec06c/data/163/060
# x trec06c/data/163/192
# x trec06c/data/163/241
# x trec06c/data/163/026
# x trec06c/data/163/123
# x trec06c/data/163/233
# x trec06c/data/163/086
# x trec06c/data/163/012
# x trec06c/data/163/231
# x trec06c/data/163/117
# x trec06c/data/163/253
# x trec06c/data/163/146
# x trec06c/data/163/016
# x trec06c/data/163/240
# x trec06c/data/163/069
# x trec06c/data/163/221
# x trec06c/data/163/021
# x trec06c/data/163/125
# x trec06c/data/163/191
# x trec06c/data/163/087
# x trec06c/data/163/118
# x trec06c/data/163/119
# x trec06c/data/163/011
# x trec06c/data/163/071
# x trec06c/data/163/014
# x trec06c/data/163/082
# x trec06c/data/163/076
# x trec06c/data/163/150
# x trec06c/data/163/211
# x trec06c/data/163/059
# x trec06c/data/163/029
# x trec06c/data/163/173
# x trec06c/data/163/010
# x trec06c/data/163/148
# x trec06c/data/163/256
# x trec06c/data/163/172
# x trec06c/data/163/124
# x trec06c/data/163/296
# x trec06c/data/163/234
# x trec06c/data/163/167
# x trec06c/data/163/079
# x trec06c/data/163/227
# x trec06c/data/163/078
# x trec06c/data/163/277
# x trec06c/data/163/126
# x trec06c/data/163/185
# x trec06c/data/163/108
# x trec06c/data/163/290
# x trec06c/data/163/228
# x trec06c/data/163/246
# x trec06c/data/163/200
# x trec06c/data/163/284
# x trec06c/data/163/056
# x trec06c/data/163/212
# x trec06c/data/163/292
# x trec06c/data/163/116
# x trec06c/data/163/095
# x trec06c/data/163/127
# x trec06c/data/163/007
# x trec06c/data/163/052
# x trec06c/data/163/156
# x trec06c/data/163/083
# x trec06c/data/163/088
# x trec06c/data/163/084
# x trec06c/data/163/115
# x trec06c/data/163/157
# x trec06c/data/163/130
# x trec06c/data/163/281
# x trec06c/data/163/081
# x trec06c/data/163/206
# x trec06c/data/163/261
# x trec06c/data/163/264
# x trec06c/data/163/110
# x trec06c/data/163/213
# x trec06c/data/163/280
# x trec06c/data/163/070
# x trec06c/data/163/030
# x trec06c/data/163/045
# x trec06c/data/163/141
# x trec06c/data/163/147
# x trec06c/data/163/289
# x trec06c/data/163/135
# x trec06c/data/163/112
# x trec06c/data/163/276
# x trec06c/data/163/048
# x trec06c/data/163/091
# x trec06c/data/163/047
# x trec06c/data/163/096
# x trec06c/data/163/040
# x trec06c/data/163/107
# x trec06c/data/163/232
# x trec06c/data/163/002
# x trec06c/data/163/017
# x trec06c/data/163/209
# x trec06c/data/163/249
# x trec06c/data/163/283
# x trec06c/data/163/137
# x trec06c/data/163/164
# x trec06c/data/163/275
# x trec06c/data/163/196
# x trec06c/data/163/121
# x trec06c/data/163/120
# x trec06c/data/163/063
# x trec06c/data/163/193
# x trec06c/data/163/201
# x trec06c/data/163/239
# x trec06c/data/163/287
# x trec06c/data/163/025
# x trec06c/data/163/020
# x trec06c/data/163/229
# x trec06c/data/163/205
# x trec06c/data/163/242
# x trec06c/data/163/171
# x trec06c/data/163/019
# x trec06c/data/163/128
# x trec06c/data/163/042
# x trec06c/data/163/142
# x trec06c/data/163/208
# x trec06c/data/163/074
# x trec06c/data/163/178
# x trec06c/data/163/250
# x trec06c/data/163/133
# x trec06c/data/163/223
# x trec06c/data/163/166
# x trec06c/data/163/266
# x trec06c/data/163/132
# x trec06c/data/163/163
# x trec06c/full/
# x trec06c/full/index
# x trec06c/delay/
# x trec06c/delay/index

# %% [markdown]
# 随机选择一个文件，查看邮件文件的具体内容。中文邮件有可能编码格式是`gb2312`，因此要注意，如果指定了`utf-8`编码，可能看到的会是乱码。

# %%
f = open('trec06c/data/050/105', 'r', encoding='gb2312', errors='ignore')
text = ''
for line in f:
    line = line.strip().strip('\n')
    if len(line) > 1:
        print(line)
        text = text + line
# Out:
# Received: from cfiin.com ([61.153.234.29])
# by spam-gw.ccert.edu.cn (MIMEDefang) with ESMTP id j7OGD6fP030969
# for <ma@ccert.edu.cn>; Sun, 28 Aug 2005 03:00:33 +0800 (CST)
# Message-ID: <200508250013.j7OGD6fP030969@spam-gw.ccert.edu.cn>
# From: =?GB2312?B?wO7Qoc2u?= <ren@cfiin.com>
# Subject: =?gb2312?B?tee2r83yxNy/qsv4xvcvtqjG2s/7yqexyjAwOjI2OjU0?=
# To: ma@ccert.edu.cn
# Content-Type: text/html;charset="GB2312"
# Reply-To: ren@cfiiiin.com
# Date: Sun, 28 Aug 2005 03:14:19 +0800
# X-Priority: 3
# X-Mailer: Microsoft Outlook Express 6.00.2800.1106
# REFRESH(3 sec): http://www.wst00.com/index.htm
# 最新窃听、监视、透视设备
# 万事通（国际）电子科技隶属迪克伟业（国际）集团子公司。专业经
# 营最新高科技电子产品业务，为香港同行业之龙头企业。本公司专业经
# 营最新高科技电子产品业务，产品包括：
# 电话通话内容监听器 GSM移动电话拦截系统                   手机窃听器
# 超远程窃听器       微型随身窃听器（世界上最小的窃听器）  透视滤镜
# 监视眼镜           WL-01高性能隔墙监听器                 电子追踪器
# 电话传真拦截器     针孔摄像机(超远程传送）               卫星全球定位系统
# 游戏机反遥控       掌中手机跟踪定位器                    电动万能开锁器
# 隐形墨水           万能钥匙                              针孔照相机
# 定期消失笔         电表控制器                            信用卡设备
# 手机窃听器（骇客手机），在手机里置入一个监听芯片，需要监听的时候，
# 我幌卤鹑说氖只号码，加入预留的密码，对方的手机将在不响铃的情况下自动
# 油ǎ处入接听状态，而对方却毫无知觉，然后对方周围的一切却尽收你的耳中
# 此手机用于追踪调查对婚姻不忠和包二奶的可收到奇特效果，还可用于家长监
# 学生是否迷恋网吧等
# 电动万能开锁器:电动工具是目前世界上最先进的工具之一，它由直流电机组
# 成，可充电，充一次电用100个小时左右。它的使用比较广阔，能开电脑打孔锁
# ⑵车锁、片子锁、挂锁、一字型门锁等。它附件有6个探针，开什么锁换什么样
# 的针，深入锁空内靠住撬杆，如果第一个弹子长，手向下倾斜；第一个弹子短，
# 向上移动。扣动开关，每秒种50下的跳动速度，是您能达到瞬间开启。
# 本工具保修一年。
# 声明：本网站所有产品均为娱乐所用，不得用于非法用途。否则后果自负。
# 联系人：陈先生
# 电话：020-33887956   传 真：020-33887959   服务热线: 13828469020
# 电子邮箱：webmaster@fd788.com
# 国际网站：http://www.wst00.com/

# %% [markdown]
# 我们可以看到，读取原始`eml`格式文件，包括邮件的正文在内，可以得到相当多的信息，比如收件人、发件人、邮件标题、时间等。
#
# 但是，最关键的中文的邮件标题会被显示成：`Subject: =?gb2312?B?tee2r83yxNy/qsv4xvcvtqjG2s/7yqexyjAwOjI2OjU0?=`这种形式，还需要一次额外转码。
#
# 正如在[使用PaddleNLP识别垃圾邮件（三）：用ELECTRA做英文邮件标题分类](https://aistudio.baidu.com/aistudio/projectdetail/1988755)中已经演示过的，使用Python自带的Email模块，中文邮件标题的显示结果也是一样。
#
# ```python
# Received: from cfiin.com ([61.153.234.29])
# by spam-gw.ccert.edu.cn (MIMEDefang) with ESMTP id j7OGD6fP030969
# for <ma@ccert.edu.cn>; Sun, 28 Aug 2005 03:00:33 +0800 (CST)
# Message-ID: <200508250013.j7OGD6fP030969@spam-gw.ccert.edu.cn>
# From: =?GB2312?B?wO7Qoc2u?= <ren@cfiin.com>
# Subject: =?gb2312?B?tee2r83yxNy/qsv4xvcvtqjG2s/7yqexyjAwOjI2OjU0?=
# To: ma@ccert.edu.cn
# Content-Type: text/html;charset="GB2312"
# Reply-To: ren@cfiiiin.com
# Date: Sun, 28 Aug 2005 03:14:19 +0800
# X-Priority: 3
# X-Mailer: Microsoft Outlook Express 6.00.2800.1106
# REFRESH(3 sec): http://www.wst00.com/index.htm
# 最新窃听、监视、透视设备
# 万事通（国际）电子科技隶属迪克伟业（国际）集团子公司。专业经
# 营最新高科技电子产品业务，为香港同行业之龙头企业。本公司专业经
# 营最新高科技电子产品业务，产品包括：
# 电话通话内容监听器 GSM移动电话拦截系统                   手机窃听器
# 超远程窃听器       微型随身窃听器（世界上最小的窃听器）  透视滤镜
# 监视眼镜           WL-01高性能隔墙监听器                 电子追踪器
# 电话传真拦截器     针孔摄像机(超远程传送）               卫星全球定位系统
# 游戏机反遥控       掌中手机跟踪定位器                    电动万能开锁器
# 隐形墨水           万能钥匙                              针孔照相机
# 定期消失笔         电表控制器                            信用卡设备
# 手机窃听器（骇客手机），在手机里置入一个监听芯片，需要监听的时候，
# 我幌卤鹑说氖只号码，加入预留的密码，对方的手机将在不响铃的情况下自动
# 油ǎ处入接听状态，而对方却毫无知觉，然后对方周围的一切却尽收你的耳中
# 此手机用于追踪调查对婚姻不忠和包二奶的可收到奇特效果，还可用于家长监
# 学生是否迷恋网吧等
# 电动万能开锁器:电动工具是目前世界上最先进的工具之一，它由直流电机组
# 成，可充电，充一次电用100个小时左右。它的使用比较广阔，能开电脑打孔锁
# ⑵车锁、片子锁、挂锁、一字型门锁等。它附件有6个探针，开什么锁换什么样
# 的针，深入锁空内靠住撬杆，如果第一个弹子长，手向下倾斜；第一个弹子短，
# 向上移动。扣动开关，每秒种50下的跳动速度，是您能达到瞬间开启。
# 本工具保修一年。
# 声明：本网站所有产品均为娱乐所用，不得用于非法用途。否则后果自负。
# 联系人：陈先生
# 电话：020-33887956   传 真：020-33887959   服务热线: 13828469020
# 电子邮箱：webmaster@fd788.com
# 国际网站：http://www.wst00.com/
# ……
# ```

# %% [markdown]
# ## 2.2 MMPI库解析提取邮件数据
# 相比之下，在提取中文邮件标题方面，MMPI库要方便得多，因为它能自动转码，直接得到解析后的中文标题，而不是需要我们对着一串奇怪的字符伤脑筋。
#
# 参考资料：[基于Python的邮件快速检测工具库](https://bbs.pediy.com/thread-264909.html)

# %%
emp = mmpi()
emp.parse('trec06c/data/001/281')
report = emp.get_report()
print("mmpi解析结果: ", report)
# Out:
# mmpi解析结果:  {'headers': [{'From': [{'name': '', 'addr': 'sun@mail.tsinghua.edu.cn'}], 'To': [{'name': '', 'addr': 'tan@ccert.edu.cn'}], 'Subject': 'Re: 教父这个烂片', 'Date': '2005-08-15 04:15:29 UTC+08:00', 'X-Originating-IP': []}], 'body': [{'type': 'text', 'content': 'Naive,ΪһӰ棬ֻӰۣΪ\nνֵڡ\nʵЩһҲ.......\n     ¥̫֪ˡΪ̸УԺֵӣFBIԺֵ\u05f7ʹ\U000a18fd̸ӳʵĹ¡˵ĸõӰɹ˾ʱ¾ֵܺƵģⲿӰʱ˺ܴǵݽһЩʩѹŵͨġ\n     ʹһЩ˵ģҲ˵̸һܺõĵӰ\n'}], 'attachments': [], 'signatures': []}

# %%
f = open('trec06c/data/001/281', 'r', encoding='gb2312', errors='ignore')
text = ''
for line in f:
    line = line.strip().strip('\n')
    if len(line) > 1:
        print(line)
        text = text + line
# Out:
# Received: from sea.net.edu.cn ([202.112.5.66])
# by spam-gw.ccert.edu.cn (MIMEDefang) with ESMTP id j7CC5Jst024179
# for <tan@ccert.edu.cn>; Mon, 15 Aug 2005 04:07:03 +0800 (CST)
# Received: from mail.tsinghua.edu.cn (mail.tsinghua.edu.cn [166.111.8.18])
# by sea.net.edu.cn (8.12.11/8.12.11) with SMTP id j7CCIo9Y018514
# for <tan@ccert.edu.cn>; Mon, 15 Aug 2005 04:20:34 +0800 (CST)
# Received: (eyou send program); Mon, 15 Aug 2005 04:15:29 +0800
# Message-ID: <323848825.13802@mail.tsinghua.edu.cn>
# Received: from 166.111.125.123 by mail.tsinghua.edu.cn with HTTP; Mon, 15 Aug 2005 04:15:29 +0800
# From: sun@mail.tsinghua.edu.cn
# To: tan@ccert.edu.cn
# Date: Mon, 15 Aug 2005 04:15:29 +0800
# Reply-To: sun@mail.tsinghua.edu.cn
# X-Priority: 3
# Subject: =?gb2312?B?UmU6IL3MuLjV4rj2wMPGrA==?=
# Content-Type: text/plain
# Naive,你以为政府会把一个电影当真，只不过政府想借助电影来制造舆论，为打击
# 所谓黑手党制造借口。
# 你问的那些美国人一点也不爱国.......
# 楼主太无知了。正是因为教父的流行，才引起了美国政府对黑手党的重视，才引起了FBI对黑手党的严追猛打。教父反映的是真实的故事。据说拍该电影的派特拉蒙公司当时本事就是受黑手党控制的，这部电影发行时遇到了很大的阻力，是导演借助一些政治力量施加压力才得以通过的
# 我问过一些美国人的，他们也都说教父是一个很好的电影

# %% [markdown]
# 然而，碰到像上面这封邮件，mmpi库在内容读取方面却“翻车”了……中英文夹杂的时候，中文邮件内容却出现了乱码……看来，要找到两全其美的办法，同时支持解析中文邮件的标题和内容，应对各种复杂场景，还需要考虑更多。
#
# 不过，既然可以提取中文邮件标题了，我们不妨试试看，只提取邮件标题，分类效果如何。毕竟，在[使用PaddleNLP识别垃圾邮件（三）：用ELECTRA做英文邮件标题分类](https://aistudio.baidu.com/aistudio/projectdetail/1988755)项目中，根据英文邮件标题进行垃圾邮件分类的准确率达到了96%以上，也许中文邮件分类也能尝试一下？
#
# 使用mmpi库，要查看邮件标题，其实非常简单，像下面这样：

# %%
report['headers'][0]['Subject']
# Out:
# 'Re: 教父这个烂片'

# %% [markdown]
# 那么接下来，就是将中文邮件标题的提取过程和处理过程串接起来，生成可以让PaddleNLP训练的数据集了。

# %% [markdown]
# ## 2.3 提取中文邮件标题，划分训练集、验证集、测试集

# %%
# 去掉非中文字符
def clean_str(string):
    if isinstance(string, bytes):
        string = string.decode('utf-8')  # 根据你的数据使用合适的编码方式
    string = re.sub(r"[^\u4e00-\u9fff]", " ", string)
    string = re.sub(r"\s{2,}", " ", string)
    return string.strip()
# 从指定路径读取邮件文件内容信息
def get_data_in_a_file(original_path, save_path='all_email.txt'):
    emp = mmpi()
    emp.parse(original_path)
    report = emp.get_report()
    # 如果可以解析到邮件头信息
    if report.get('headers') is not None:
        return clean_str(report['headers'][0]['Subject'])

# %% [markdown]
# 中文邮件标题提取的时候有时候会提取到`''`——<font color=red>注意是`''`不是None!</font>
#
# 所以要进行过滤，经测试，处理了这个问题之后，提取的数据中就没有脏数据了！可以放心使用![https://ai-studio-static-online.cdn.bcebos.com/d500f483e55544a5b929abad59de208f180c068cc81648009fab60a0b6d9bda2](https://ai-studio-static-online.cdn.bcebos.com/d500f483e55544a5b929abad59de208f180c068cc81648009fab60a0b6d9bda2)

# %%
# 读取标签文件信息
f = open('trec06c/full/index', 'r')
for line in f:
    str_list = line.split(" ")
    # 设置垃圾邮件的标签为0
    if str_list[0] == 'spam':
        label = '0'
    # 设置正常邮件标签为1
    elif str_list[0] == 'ham':
        label = '1'
    text = get_data_in_a_file('trec06c/full/' + str(str_list[1].split("\n")[0]))
    # 注意，处理逻辑不是text非空，实际上这样还是会生成脏数据，应该用下面的方法
    if text is not None and label is not None:
        with open("all_email.txt", "a+",encoding='utf-8') as f:
            f.write(text + '\t' + label + '\n')
    else:
        print("text or label is None, cannot write to file.")
# Out:
# text or label is None, cannot write to file.
# text or label is None, cannot write to file.
# text or label is None, cannot write to file.
# text or label is None, cannot write to file.
# text or label is None, cannot write to file.
# text or label is None, cannot write to file.
# text or label is None, cannot write to file.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14480\794028887.py in <module>
#       9     elif str_list[0] == 'ham':
#      10         label = '1'
# ---> 11     text = get_data_in_a_file('trec06c/full/' + str(str_list[1].split("\n")[0]))
#      12     # 注意，处理逻辑不是text非空，实际上这样还是会生成脏数据，应该用下面的方法
#      13     if text is not None and label is not None:
#
# ~\AppData\Local\Temp\ipykernel_14480\402716656.py in get_data_in_a_file(original_path, save_path)
#       9 def get_data_in_a_file(original_path, save_path='all_email.txt'):
#      10     emp = mmpi()
# ---> 11     emp.parse(original_path)
#      12     report = emp.get_report()
#      13     # 如果可以解析到邮件头信息
#
# D:\pythonProject\.venv\lib\site-packages\mmpi\main.py in parse(self, filename)
#      50         if data.get('content', b''):
#      51             self.process(data)
# ---> 52             self.signatures(self.results)
#      53             self.reports['signatures'] = self.get_signatures()
#      54
#
# D:\pythonProject\.venv\lib\site-packages\mmpi\main.py in signatures(self, data)
#      41
#      42     def signatures(self, data):
# ---> 43         RunSignatures(data).run()
#      44
#      45     def parse(self, filename):
#
# D:\pythonProject\.venv\lib\site-packages\mmpi\core\plugins.py in __init__(self, results)
#     195         self.signatures = []
#     196         for signature in self.available_signatures:
# --> 197             self.signatures.append(signature(self))
#     198
#     199     @classmethod
#
# D:\pythonProject\.venv\lib\site-packages\mmpi\common\abstracts.py in __init__(self, caller)
#      80         @param caller: calling object. Stores results in caller.results
#      81         """
# ---> 82         self.marks = []
#      83         self.matched = False
#      84         self._caller = caller
#
# KeyboardInterrupt:

# %%
data_list_path="./"

with open(os.path.join(data_list_path, 'eval_list.txt'), 'w', encoding='utf-8') as f_eval:
    f_eval.seek(0)
    f_eval.truncate()
    
with open(os.path.join(data_list_path, 'train_list.txt'), 'w', encoding='utf-8') as f_train:
    f_train.seek(0)
    f_train.truncate() 

with open(os.path.join(data_list_path, 'test_list.txt'), 'w', encoding='utf-8') as f_test:
    f_test.seek(0)
    f_test.truncate()

with open(os.path.join(data_list_path, 'all_email.txt'), 'r', encoding='utf-8') as f_data:
    lines = f_data.readlines()

i = 0
with open(os.path.join(data_list_path, 'eval_list.txt'), 'a', encoding='utf-8') as f_eval,open(os.path.join(data_list_path, 'test_list.txt'), 'a', encoding='utf-8') as f_test,open(os.path.join(data_list_path, 'train_list.txt'), 'a', encoding='utf-8') as f_train:
    for line in lines:
        words = line.split('\t')[-1].replace('\n', '')
        label = line.split('\t')[0]
        labs = ""
        # 划分验证集
        if i % 10 == 1:
            labs = label + '\t' + words + '\n'
            f_eval.write(labs)
        # 划分测试集
        elif i % 10 == 2:
            labs = label + '\t' + words + '\n'
            f_test.write(labs)
        # 划分训练集
        else:
            labs = label + '\t' + words + '\n'
            f_train.write(labs)
        i += 1
    
print("数据列表生成完成！")
# Out:
# 数据列表生成完成！

# %% [markdown]
# ## 2.4 自定义数据集
# 在之前的几个项目里，有很多读者反馈项目里能正常执行的代码，到本地就会报错，尤其是自定义数据集部分。
#
# 其实，这是因为项目环境和本地安装环境的不同。在之前的项目里，paddlepaddle的版本一般是2.0.2，而paddlenlp的版本是2.0rc，正因如此，原来才能这样自定义数据集：
#
# ```python
# class SelfDefinedDataset(paddle.io.Dataset):
#     def __init__(self, data):
#         super(SelfDefinedDataset, self).__init__()
#         self.data = data
#
#     def __getitem__(self, idx):
#         return self.data[idx]
#
#     def __len__(self):
#         return len(self.data)
#
#     def get_labels(self):
#         return ["0", "1"]
#
# def txt_to_list(file_name):
#     res_list = []
#     for line in open(file_name):
#         res_list.append(line.strip().split('\t'))
#     return res_list
#
# trainlst = txt_to_list('train_list.txt')
# devlst = txt_to_list('eval_list.txt')
# testlst = txt_to_list('test_list.txt')
#
# train_ds, dev_ds, test_ds = SelfDefinedDataset.get_datasets([trainlst, devlst, testlst])
# ```

# %% [markdown]
# 但如果读者使用的是本地环境，安装的paddlenlp版本可能是2.0.2，就像当前项目的环境，那么自定义数据集时就会出现报错：
# ```bash
# ---------------------------------------------------------------------------AttributeError                            Traceback (most recent call last)<ipython-input-33-f4bfc4346c92> in <module>
#      23 testlst = txt_to_list('test_list.txt')
#      24
# ---> 25 train_ds, dev_ds, test_ds = SelfDefinedDataset.get_datasets([trainlst, devlst, testlst])
# AttributeError: type object 'SelfDefinedDataset' has no attribute 'get_datasets'
# ```
#
# 也正是因此，我们需要参考最新[paddlenlp文档](https://paddlenlp.readthedocs.io/zh/latest/data_prepare/dataset_self_defined.html)自定义数据集

# %% [markdown]
# ### 2.4.1 [从本地文件创建数据集](https://paddlenlp.readthedocs.io/zh/latest/data_prepare/dataset_self_defined.html#id2)
#
# 从本地文件创建数据集时，官方**推荐**根据本地数据集的格式给出读取function并传入 `load_dataset()` 中创建数据集。

# %%
from paddlenlp.datasets import load_dataset

def read(data_path):
    with open(data_path, 'r', encoding='utf-8') as f:
        # 跳过列名
        next(f)
        for line in f:
            words, labels = line.strip('\n').split('\t')
            words = words.split('\002')
            labels = labels.split('\002')
            yield {'text': words[0], 'label': labels[0]}

# data_path为read()方法的参数
train_ds = load_dataset(read,data_path='train_list.txt',splits='train',lazy=False)
dev_ds = load_dataset(read,data_path='eval_list.txt',splits='dev',lazy=False)
test_ds = load_dataset(read,data_path='test_list.txt',splits='test',lazy=False)

# %% [markdown]
# 官方文档说明了这么做的理由：
# - 将数据读取代码写成生成器(generator)的形式，这样可以更好的构建 MapDataset 和 IterDataset 两种数据集
# - 将单条数据写成字典的格式，这样可以更方便的监测数据流向
# - 事实上，MapDataset在绝大多数时候都可以满足要求。一般只有在数据集过于庞大无法一次性加载进内存的时候我们才考虑使用IterDataset。任何人都可以方便的定义属于自己的数据集。
#
# > 需要注意的是，只有PaddleNLP内置的数据集具有将数据中的label自动转为id的功能（详细条件参见 [创建DatasetBuilder](https://paddlenlp.readthedocs.io/zh/latest/community/contribute_datasets/how_to_write_a_DatasetBuilder.html)）。
# >
# > 自定义数据集需要在自定义的convert to feature方法中添加label转id的功能——当然，在本项目中，已经直接在前面的数据预处理阶段将label转id，就免去了这个步骤。

# %% [markdown]
# ### 2.4.2 从 [`paddle.io.Dataset/IterableDataset` 创建数据集](https://paddlenlp.readthedocs.io/zh/latest/data_prepare/dataset_self_defined.html#paddle-io-dataset-iterabledataset)
#
# 在之前的项目中，我们其实都是用的这种方法自定义数据集。事实上，是用PaddleNLP内置的 `MapDataset` 和 `IterDataset`API。由于API有更新，注意到这里不需要原来的`get_datasets`函数了，直接用。
# ```python
# class SelfDefinedDataset(paddle.io.Dataset):
#     def __init__(self, path):
#
#         def load_data_from_source(path):
#             data = []
#             for line in open(path):
#                 data.append(line.strip().split('\t'))
#             return data
#
#         self.data = load_data_from_source(path)
#
#     def __getitem__(self, idx):
#         return self.data[idx]
#
#     def __len__(self):
#         return len(self.data)
# ```
# ```python
# train_ds = SelfDefinedDataset('train_list.txt')
# dev_ds = SelfDefinedDataset('eval_list.txt')
# test_ds = SelfDefinedDataset('test_list.txt')
# ```
# 效果如下
# ```python
# 训练集数据：[['非财务经理的财务管理 沙盘模拟', '0'], ['低点代开发票', '0'], ['一边上网冲浪 一边赚钱 何乐而不为', '0']]
#
# 验证集数据:[['问一部魏宗万的电影名称', '1'], ['低点代开发票', '0'], ['深圳协恒实业有限公司', '0']]
#
# 测试集数据:[['公司业务 代开发票', '0'], ['合作', '0'], ['公司业务 优惠发票', '0']]
# ```

# %% [markdown]
# ## 2.5 训练数据分析

# %%
#看看数据长什么样子，分别打印训练集、验证集、测试集的前3条数据。
print("训练集数据：{}\n".format(train_ds[0:3]))
print("验证集数据:{}\n".format(dev_ds[0:3]))
print("测试集数据:{}\n".format(test_ds[0:3]))

print("训练集样本个数:{}".format(len(train_ds)))
print("验证集样本个数:{}".format(len(dev_ds)))
print("测试集样本个数:{}".format(len(test_ds)))
# Out:
# 训练集数据：[{'text': '业务', 'label': '0'}, {'text': '写在 好想好想 之后的补充', 'label': '1'}, {'text': '优惠代开发票', 'label': '0'}]
#
# 验证集数据:[{'text': '一边上网冲浪 一边赚钱 何乐而不为', 'label': '0'}, {'text': '北京机票酒店旅游', 'label': '0'}, {'text': '系统集成大全', 'label': '0'}]
#
# 测试集数据:[{'text': '问一部魏宗万的电影名称', 'label': '1'}, {'text': '长久收益', 'label': '0'}, {'text': '深圳协恒实业有限公司', 'label': '0'}]
#
# 训练集样本个数:51656
# 验证集样本个数:6457
# 测试集样本个数:6456

# %%
# 统计训练集正负样本数量
spam = 0
for data in train_ds:
    if data['label'] == '0':
        spam += 1
print("训练集垃圾邮件数量:{}".format(spam))
print("训练集正常邮件数量:{}".format(len(train_ds) - spam))
# Out:
# 训练集垃圾邮件数量:34263
# 训练集正常邮件数量:17393

# %% [markdown]
# 情况稍微比较不妙，看来中文邮件分类的数据集中，正负样本比例不能算特别均衡，但是又好像在可以接受的范围之内，我们可以继续往下看。

# %% [markdown]
# # 三、模型训练
# ## 3.1 模型选择
# 在[PaddleNLP Transformer API](https://gitee.com/paddlepaddle/PaddleNLP/blob/develop/docs/transformers.md)中选择RoBERTa算法，考虑到中文邮件标题分类这个场景，要分类的基本都是非常短的语句，也许不宜使用太深的神经网络，因此`rbt3`似乎就是一个很好的选择。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/c374e04164a547edbf91ea1a6811c1b8c79d6e3b6c2d4742897b17b10319a9e9)
# ## 3.2 准备PaddleNLP模型库
# 一旦弄清楚如何自定义PaddleNLP数据集，就可以根据PaddleNLP模型库提供的预训练模型使用方法，对[使用预训练模型Fine-tune完成中文文本分类任务](https://github.com/PaddlePaddle/PaddleNLP/tree/develop/examples/text_classification/pretrained_models/)目录下的文件稍作修改，开始迁移学习训练。
#
# 根据文档说明，主要步骤如下：
#
# 1. 加载数据集：PaddleNLP内置了多种数据集，内置的数据集可以一键导入，在本项目中，则需要用2.4.1的处理方法进行替代。
#
# ```python
#     # 注释掉内置数据集的导入
#     # train_ds, dev_ds = load_dataset("chnsenticorp", splits=["train", "dev"])
#
#     # data_path为read()方法的参数，用本地数据集导入进行替换。
#     train_ds = load_dataset(read,data_path='/home/aistudio/train_list.txt',splits='train',lazy=False)
#     dev_ds = load_dataset(read,data_path='/home/aistudio/eval_list.txt',splits='dev',lazy=False)
#     test_ds = load_dataset(read,data_path='/home/aistudio/test_list.txt',splits='test',lazy=False)
# ```
#
# 2. 加载预训练模型：PaddleNLP的预训练模型可以很容易地通过 `from_pretrained()` 方法加载。 第一个参数是汇总表中对应的 `Pretrained Weight`，可加载对应的预训练权重。 `BertForSequenceClassification` 初始化 `__init__` 所需的其他参数，如 `num_classes` 等， 也是通过 `from_pretrained()` 传入。`Tokenizer` 使用同样的 `from_pretrained` 方法加载。
#
# ```python
#     model = ppnlp.transformers.RobertaForSequenceClassification.from_pretrained('rbt3', num_class=2)
#     tokenizer = ppnlp.transformers.RobertaTokenizer.from_pretrained('rbt3')
# ```
#
# 3. 通过 `Dataset` 的 `map` 函数，使用 `tokenizer` 将 `dataset` 从原始文本处理成模型的输入。
#
# 4. 定义 `BatchSampler` 和 `DataLoader`，shuffle数据、组合Batch。
#
# 5. 定义训练所需的优化器，loss函数等，就可以开始进行模型fine-tune任务——在本项目中，可以结合中文邮件标题文本的特点，重点注意修改`max_seq_length`和`batch_size`超参数。
#
# 6. 【项目新增】引入VisualDL进行训练过程的可视化。
#
# ```python
# with LogWriter(logdir="./logdir") as writer:
# 	……
# 	#记录训练过程
# 	writer.add_scalar(tag="train/loss", step=global_step, value=loss)
# 	writer.add_scalar(tag="train/acc", step=global_step, value=acc)
# 	……
# 	#记录评估过程
# 	writer.add_scalar(tag="eval/loss", step=epoch, value=eval_loss)
# 	writer.add_scalar(tag="eval/acc", step=epoch, value=eval_acc)
# ```

# %%
# 拉取模型库
# !git clone https://gitee.com/paddlepaddle/PaddleNLP.git
# Out:
# Cloning into 'PaddleNLP'...
# Updating files:  50% (2321/4640)
# Updating files:  51% (2367/4640)
# Updating files:  52% (2413/4640)
# Updating files:  53% (2460/4640)
# Updating files:  54% (2506/4640)
# Updating files:  55% (2552/4640)
# Updating files:  56% (2599/4640)
# Updating files:  57% (2645/4640)
# Updating files:  58% (2692/4640)
# Updating files:  59% (2738/4640)
# Updating files:  60% (2784/4640)
# Updating files:  61% (2831/4640)
# Updating files:  62% (2877/4640)
# Updating files:  63% (2924/4640)
# Updating files:  64% (2970/4640)
# Updating files:  65% (3016/4640)
# Updating files:  66% (3063/4640)
# Updating files:  67% (3109/4640)
# Updating files:  68% (3156/4640)
# Updating files:  69% (3202/4640)
# Updating files:  70% (3248/4640)
# Updating files:  71% (3295/4640)
# Updating files:  72% (3341/4640)
# Updating files:  73% (3388/4640)
# Updating files:  74% (3434/4640)
# Updating files:  75% (3480/4640)
# Updating files:  76% (3527/4640)
# Updating files:  77% (3573/4640)
# Updating files:  78% (3620/4640)
# Updating files:  79% (3666/4640)
# Updating files:  80% (3712/4640)
# Updating files:  81% (3759/4640)
# Updating files:  82% (3805/4640)
# Updating files:  83% (3852/4640)
# Updating files:  84% (3898/4640)
# Updating files:  85% (3944/4640)
# Updating files:  86% (3991/4640)
# Updating files:  87% (4037/4640)
# Updating files:  88% (4084/4640)
# Updating files:  89% (4130/4640)
# Updating files:  90% (4176/4640)
# Updating files:  91% (4223/4640)
# Updating files:  92% (4269/4640)
# Updating files:  93% (4316/4640)
# Updating files:  94% (4362/4640)
# Updating files:  95% (4408/4640)
# Updating files:  96% (4455/4640)
# Updating files:  97% (4501/4640)
# Updating files:  98% (4548/4640)
# Updating files:  98% (4562/4640)
# Updating files:  99% (4594/4640)
# Updating files: 100% (4640/4640)
# Updating files: 100% (4640/4640), done.

# %%
# 将文本分类迁移学习训练目录单独移出来，便于查看和修改
# 本项目修改后的结果，可以直接查看./pretrained_models目录
# !mv PaddleNLP/examples/text_classification/pretrained_models ./pretrained_models

# %% [markdown]
# ## 3.3 开始训练

# %%
# !python pretrained_models/train.py
# Out:
# WARNING: OMP_NUM_THREADS set to 12, not 1. The computation speed will not be optimized if you use data parallel. It will fail if this PaddlePaddle binary is compiled with OpenBlas since OpenBlas does not support multi-threads.
# PLEASE USE OMP_NUM_THREADS WISELY.
# D:\pythonProject\.venv\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Traceback (most recent call last):
#   File "pretrained_models/train.py", line 283, in <module>
#     do_train()
#   File "pretrained_models/train.py", line 176, in do_train
#     model = ppnlp.transformers.RobertaForSequenceClassification.from_pretrained('rbt3', num_class=2)
#   File "D:\pythonProject\.venv\lib\site-packages\paddlenlp\transformers\model_utils.py", line 1901, in from_pretrained
#     **kwargs,
#   File "D:\pythonProject\.venv\lib\site-packages\paddlenlp\transformers\configuration_utils.py", line 749, in from_pretrained
#     config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#   File "D:\pythonProject\.venv\lib\site-packages\paddlenlp\transformers\configuration_utils.py", line 776, in get_config_dict
#     pretrained_model_name_or_path, cache_dir=cache_dir, from_hf_hub=from_hf_hub, **kwargs
#   File "D:\pythonProject\.venv\lib\site-packages\paddlenlp\transformers\configuration_utils.py", line 850, in _get_config_dict
#     raise FileNotFoundError(f"configuration file<{CONFIG_NAME}> or <{LEGACY_CONFIG_NAME}> not found")
# FileNotFoundError: configuration file<config.json> or <model_config.json> not found

# %% [markdown]
# 最终，模型在测试集上准确率达到98.3%以上，分类效果还不错。
# ```python
# test result...
# eval loss: 0.06442, accu: 0.98347
# ```

# %% [markdown]
# ![](https://ai-studio-static-online.cdn.bcebos.com/d8decdc657ad49e2b0f5922c299db091984d7b67da2f427f8559efb31ff13471)

# %% [markdown]
# 训练过程中，可支持配置的参数如下：
# - `save_dir`：可选，保存训练模型的目录；默认保存在当前目录checkpoints文件夹下。
# - `max_seq_length`：可选，ERNIE/BERT模型使用的最大序列长度，最大不能超过512, 若出现显存不足，请适当调低这一参数；默认为128。
# - `batch_size`：可选，批处理大小，请结合显存情况进行调整，若出现显存不足，请适当调低这一参数；默认为32。
# - `learning_rate`：可选，Fine-tune的最大学习率；默认为5e-5。
# - `weight_decay`：可选，控制正则项力度的参数，用于防止过拟合，默认为0.00。
# - `epochs`: 训练轮次，默认为3。
# - `warmup_proption`：可选，学习率warmup策略的比例，如果0.1，则学习率会在前10%训练step的过程中从0慢慢增长到learning\_rate, 而后再缓慢衰减，默认为0.1。
# - `init_from_ckpt`：可选，模型参数路径，热启动模型训练；默认为None。
# - `seed`：可选，随机种子，默认为1000.
# - `device`: 选用什么设备进行训练，可选cpu或gpu。如使用gpu训练则参数gpus指定GPU卡号。

# %% [markdown]
# ## 3.4 模型保存

# %% [markdown]
# 训练过程中会自动保存模型在指定的`save_dir`中。 如：
#
# ```
# checkpoints/
# ├── model_100
# │   ├── model_config.json
# │   ├── model_state.pdparams
# │   ├── tokenizer_config.json
# │   └── vocab.txt
# └── ...
# ```
#
# 我们不妨来看看json文件的具体内容，比如`model_config.json`定义了我们使用的`rbt3`模型进行序列分类任务的具体信息
# ```json
# {  "init_args": [
#     {
#       "attention_probs_dropout_prob": 0.1,
#       "hidden_act": "gelu",
#       "hidden_dropout_prob": 0.1,
#       "hidden_size": 768,
#       "initializer_range": 0.02,
#       "intermediate_size": 3072,
#       "max_position_embeddings": 512,
#       "num_attention_heads": 12,
#       "num_hidden_layers": 3,
#       "type_vocab_size": 2,
#       "vocab_size": 21128,
#       "pad_token_id": 0,
#       "init_class": "RobertaModel"
#     }
#   ],
#   "init_class": "RobertaForSequenceClassification"
# }
# ```
# 而`tokenizer_config.json`主要为了定位`vocab.txt`
# ```json
# {
#     "do_lower_case":true
#     "vocab_file":"/home/aistudio/.paddlenlp/models/rbt3/vocab.txt"
#     "init_class":"RobertaTokenizer"
# }
# ```

# %% [markdown]
# ## 3.5 模型导出和可视化
# 使用动态图训练结束之后，可以运行`pretrained_models/export_model.py`将动态图参数导出成静态图参数，静态图参数保存在`--output_path`指定路径中，在保存的静态图信息中，我们还可以在VisualDL中查看模型的网络结构。
#
# 很显然，`rbt3`的网络结构要简单多了，毕竟layer只有3层。
#
# 对于PaddleNLP模型库提供的默认配置，在`pretrained_models/export_model.py`中，最重要的是修改下面两行代码：
# ```python
#     # 根据数据集，指定标签的写法
#     label_map = {0: 'spam', 1: 'ham'}
#     # 加载训练时选定的预训练模型
#     model = ppnlp.transformers.RobertaForSequenceClassification.from_pretrained('rbt3', num_class=len(label_map))
# ```

# %%
# 模型导出
# !python pretrained_models/export_model.py --params_path=./checkpoint/model_360/model_state.pdparams --output_path=./checkpoint/static_graph_params
# Out:
# Loaded parameters from ./checkpoint/model_360/model_state.pdparams
# WARNING: OMP_NUM_THREADS set to 12, not 1. The computation speed will not be optimized if you use data parallel. It will fail if this PaddlePaddle binary is compiled with OpenBlas since OpenBlas does not support multi-threads.
# PLEASE USE OMP_NUM_THREADS WISELY.
# D:\NLP_email\.venv\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# [2024-10-18 20:00:24,733] [    INFO] - Already cached C:\Users\biang\.paddlenlp\models\chinese-electra-small\model_state.pdparams
# [2024-10-18 20:00:24,733] [    INFO] - Loading weights file model_state.pdparams from cache at C:\Users\biang\.paddlenlp\models\chinese-electra-small\model_state.pdparams
# [2024-10-18 20:00:24,799] [    INFO] - Loaded weights file from disk, setting weights to model.
# W1018 20:00:24.801165 24428 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.6, Runtime API Version: 11.7
# W1018 20:00:24.805166 24428 gpu_resources.cc:149] device: 0, cuDNN Version: 8.7.
# [2024-10-18 20:00:26,543] [ WARNING] - Some weights of the model checkpoint at chinese-electra-small were not used when initializing ElectraForSequenceClassification: ['electra.pooler.dense.weight', 'electra.pooler.dense.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [2024-10-18 20:00:26,543] [ WARNING] - Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at chinese-electra-small and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# I1018 20:00:30.090065 24428 interpretercore.cc:237] New Executor is Running.

# %% [markdown]
# ![](https://ai-studio-static-online.cdn.bcebos.com/2003c506667a4ae296d1ade3d63070aac5047d93999a455b97393816247a2232)

# %% [markdown]
# ## 3.6 模型的预测和部署
# 在预测阶段，本项目希望把数据处理流程在预测和部署时串接起来。因此，无论是动态图预测，还是动态图转静态图部署之后的预测，都有下列事项需要注意：
#
# 1. 配置预训练模型为`rbt3`，需要更换model 和 tokenizer
#
# 2. 将数据处理流程加入预测阶段代码中，当然，考虑到带预测的邮件文件数量比较多，这里加入了限制条件，选取三封邮件进行抽样，实际使用时可以根据需要，删除限制条件。
#
# 修改后的文件，参考`pretrained_models/predict.py`和`pretrained_models/deploy/python/predict.py`，部分关键代码：
# ```python
# # 引入数据处理工具库
# from mmpi import mmpi
# import re
# 	......
# # 定义处理函数
# # 去掉非中文字符
# def clean_str(string):
#     string = re.sub(r"[^\u4e00-\u9fff]", " ", string)
#     string = re.sub(r"\s{2,}", " ", string)
#     return string.strip()
# # 从指定路径读取邮件文件内容信息
# def get_data_in_a_file(original_path):
#     emp = mmpi()
#     emp.parse(original_path)
#     report = emp.get_report()
#     # 如果可以解析到邮件头信息
#     if report.get('headers') is not None:
#         return clean_str(report['headers'][0]['Subject'])
# 	......
# # 将处理结果传入输入预测的数据list中
# data = []
# for line in open('/home/aistudio/trec06c/full/index', 'r'):
# 	str_list = line.split(" ")
# 	if str_list[1].split("\n")[0] in ['../data/000/011','../data/000/021','../data/000/031']:
# 	text = get_data_in_a_file('trec06c/full/' + str(str_list[1].split("\n")[0]))
# 	data.append(text)
# 	......
# ```
# ### 3.6.1 动态图预测
# 可以直接调用predict函数输出预测结果。

# %%
# !python pretrained_models/predict.py --params_path=./checkpoint/model_360/model_state.pdparams
# Out:
# Loaded parameters from ./checkpoint/model_360/model_state.pdparams
# Data: 低点代开发票 	 Lable: 垃圾邮件
# Data: 深圳协恒实业有限公司 	 Lable: 垃圾邮件
# Data: 帮帮忙啊 	 Lable: 正常邮件
# WARNING: OMP_NUM_THREADS set to 12, not 1. The computation speed will not be optimized if you use data parallel. It will fail if this PaddlePaddle binary is compiled with OpenBlas since OpenBlas does not support multi-threads.
# PLEASE USE OMP_NUM_THREADS WISELY.
# D:\NLP_email\.venv\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# [2024-10-18 20:05:23,756] [    INFO] - Already cached C:\Users\biang\.paddlenlp\models\chinese-electra-small\vocab.txt
# [2024-10-18 20:05:23,766] [    INFO] - tokenizer config file saved in C:\Users\biang\.paddlenlp\models\chinese-electra-small\tokenizer_config.json
# [2024-10-18 20:05:23,767] [    INFO] - Special tokens file saved in C:\Users\biang\.paddlenlp\models\chinese-electra-small\special_tokens_map.json
# [2024-10-18 20:05:23,815] [    INFO] - Already cached C:\Users\biang\.paddlenlp\models\chinese-electra-small\model_state.pdparams
# [2024-10-18 20:05:23,815] [    INFO] - Loading weights file model_state.pdparams from cache at C:\Users\biang\.paddlenlp\models\chinese-electra-small\model_state.pdparams
# [2024-10-18 20:05:23,849] [    INFO] - Loaded weights file from disk, setting weights to model.
# W1018 20:05:23.851169 25076 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.6, Runtime API Version: 11.7
# W1018 20:05:23.855170 25076 gpu_resources.cc:149] device: 0, cuDNN Version: 8.7.
# [2024-10-18 20:05:25,423] [ WARNING] - Some weights of the model checkpoint at chinese-electra-small were not used when initializing ElectraForSequenceClassification: ['electra.pooler.dense.bias', 'electra.pooler.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [2024-10-18 20:05:25,423] [ WARNING] - Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at chinese-electra-small and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# D:\NLP_email\.venv\lib\site-packages\paddlenlp\transformers\tokenizer_utils_base.py:2293: FutureWarning: The `max_seq_len` argument is deprecated and will be removed in a future version, please use `max_length` instead.
#   warnings.warn(
# D:\NLP_email\.venv\lib\site-packages\paddlenlp\transformers\tokenizer_utils_base.py:1865: UserWarning: Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
#   warnings.warn(

# %%
# Out:
# [2024-10-15 10:49:39,160] [    INFO] - Downloading tokenizer_config.json from https://bj.bcebos.com/paddlenlp/models/community/rbt3/tokenizer_config.json
# [2024-10-15 10:49:39,395] [   ERROR] - Downloading from https://bj.bcebos.com/paddlenlp/models/community/rbt3/tokenizer_config.json failed with code 404!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# D:\pythonProject\.venv\lib\site-packages\paddlenlp\transformers\roberta\tokenizer.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602             try:
# --> 603                 resolved_config_file = get_path_from_url(config_file, default_root)
#     604             except RuntimeError as err:
#
# D:\pythonProject\.venv\lib\site-packages\paddlenlp\utils\downloader.py in get_path_from_url(url, root_dir, md5sum, check_exist)
#     132     else:
# --> 133         fullpath = _download(url, root_dir, md5sum)
#     134
#
# D:\pythonProject\.venv\lib\site-packages\paddlenlp\utils\downloader.py in _download(url, path, md5sum)
#     194         if req.status_code != 200:
# --> 195             raise RuntimeError("Downloading from {} failed with code " "{}!".format(url, req.status_code))
#     196
#
# RuntimeError: Downloading from https://bj.bcebos.com/paddlenlp/models/community/rbt3/tokenizer_config.json failed with code 404!
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13788\2852908615.py in <module>
# ----> 1 tokenizer = paddlenlp.transformers.RobertaTokenizer.from_pretrained('rbt3')
#
# D:\pythonProject\.venv\lib\site-packages\paddlenlp\transformers\roberta\tokenizer.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     605                 logger.error(err)
#     606                 raise RuntimeError(
# --> 607                     f"Can't find load tokenizer_config_file for '{pretrained_model_name_or_path}'.\n"
#     608                     f"Please make sure that '{pretrained_model_name_or_path}' is:\n"
#     609                     "a correct model-identifier of community-contributed pretrained models.\n"
#
# RuntimeError: Can't find load tokenizer_config_file for 'rbt3'.
# Please make sure that 'rbt3' is:
# a correct model-identifier of community-contributed pretrained models.

# %% [markdown]
# ### 3.6.2 python部署预测

# %%
# !python pretrained_models/deploy/python/predict.py --model_file=./checkpoint/static_graph_params.pdmodel --params_file=./checkpoint/static_graph_params.pdiparams
# Out:
# WARNING: OMP_NUM_THREADS set to 12, not 1. The computation speed will not be optimized if you use data parallel. It will fail if this PaddlePaddle binary is compiled with OpenBlas since OpenBlas does not support multi-threads.
# PLEASE USE OMP_NUM_THREADS WISELY.
# D:\NLP_email\.venv\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# ee--- Running analysis [ir_graph_build_pass]e
# I1018 20:01:48.065541 19492 executor.cc:187] Old Executor is Running.
# ee--- Running analysis [ir_analysis_pass]e
# e--- Running IR pass [map_op_to_another_pass]e
# e--- Running IR pass [identity_scale_op_clean_pass]e
# e--- Running IR pass [is_test_pass]e
# e--- Running IR pass [simplify_with_basic_ops_pass]e
# e--- Running IR pass [delete_quant_dequant_linear_op_pass]e
# e--- Running IR pass [delete_weight_dequant_linear_op_pass]e
# e--- Running IR pass [constant_folding_pass]e
# e--- Running IR pass [silu_fuse_pass]e
# e--- Running IR pass [conv_bn_fuse_pass]e
# e--- Running IR pass [conv_eltwiseadd_bn_fuse_pass]e
# e--- Running IR pass [embedding_eltwise_layernorm_fuse_pass]e
# I1018 20:01:48.206991 19492 fuse_pass_base.cc:59] ---  detected 1 subgraphs
# e--- Running IR pass [multihead_matmul_fuse_pass_v2]e
# I1018 20:01:48.707295 19492 fuse_pass_base.cc:59] ---  detected 12 subgraphs
# e--- Running IR pass [vit_attention_fuse_pass]e
# e--- Running IR pass [fused_multi_transformer_encoder_pass]e
# e--- Running IR pass [fused_multi_transformer_decoder_pass]e
# e--- Running IR pass [fused_multi_transformer_encoder_fuse_qkv_pass]e
# e--- Running IR pass [fused_multi_transformer_decoder_fuse_qkv_pass]e
# e--- Running IR pass [multi_devices_fused_multi_transformer_encoder_pass]e
# e--- Running IR pass [multi_devices_fused_multi_transformer_encoder_fuse_qkv_pass]e
# e--- Running IR pass [multi_devices_fused_multi_transformer_decoder_fuse_qkv_pass]e
# e--- Running IR pass [fuse_multi_transformer_layer_pass]e
# e--- Running IR pass [gpu_cpu_squeeze2_matmul_fuse_pass]e
# e--- Running IR pass [gpu_cpu_reshape2_matmul_fuse_pass]e
# e--- Running IR pass [gpu_cpu_flatten2_matmul_fuse_pass]e
# e--- Running IR pass [gpu_cpu_map_matmul_v2_to_mul_pass]e
# I1018 20:01:50.917270 19492 fuse_pass_base.cc:59] ---  detected 39 subgraphs
# e--- Running IR pass [gpu_cpu_map_matmul_v2_to_matmul_pass]e
# e--- Running IR pass [matmul_scale_fuse_pass]e
# e--- Running IR pass [multihead_matmul_fuse_pass_v3]e
# e--- Running IR pass [gpu_cpu_map_matmul_to_mul_pass]e
# e--- Running IR pass [fc_fuse_pass]e
# I1018 20:01:51.007226 19492 fuse_pass_base.cc:59] ---  detected 39 subgraphs
# e--- Running IR pass [fc_elementwise_layernorm_fuse_pass]e
# I1018 20:01:51.049742 19492 fuse_pass_base.cc:59] ---  detected 24 subgraphs
# e--- Running IR pass [conv_elementwise_add_act_fuse_pass]e
# e--- Running IR pass [conv_elementwise_add2_act_fuse_pass]e
# e--- Running IR pass [conv_elementwise_add_fuse_pass]e
# e--- Running IR pass [transpose_flatten_concat_fuse_pass]e
# e--- Running IR pass [conv2d_fusion_layout_transfer_pass]e
# e--- Running IR pass [transfer_layout_elim_pass]e
# e--- Running IR pass [auto_mixed_precision_pass]e
# e--- Running IR pass [inplace_op_var_pass]e
# I1018 20:01:51.054744 19492 fuse_pass_base.cc:59] ---  detected 1 subgraphs
# ee--- Running analysis [save_optimized_model_pass]e
# W1018 20:01:51.055744 19492 save_optimized_model_pass.cc:28] save_optim_cache_model is turned off, skip save_optimized_model_pass
# ee--- Running analysis [ir_params_sync_among_devices_pass]e
# I1018 20:01:51.055744 19492 ir_params_sync_among_devices_pass.cc:51] Sync params from CPU to GPU
# ee--- Running analysis [adjust_cudnn_workspace_size_pass]e
# ee--- Running analysis [inference_op_replace_pass]e
# ee--- Running analysis [ir_graph_to_program_pass]e
# I1018 20:01:51.110343 19492 analysis_predictor.cc:1660] ======= optimize end =======
# I1018 20:01:51.111343 19492 naive_executor.cc:164] ---  skip [feed], feed -> token_type_ids
# I1018 20:01:51.111343 19492 naive_executor.cc:164] ---  skip [feed], feed -> input_ids
# I1018 20:01:51.111343 19492 naive_executor.cc:164] ---  skip [linear_149.tmp_1], fetch -> fetch
# [2024-10-18 20:01:51,112] [    INFO] - Already cached C:\Users\biang\.paddlenlp\models\chinese-electra-small\vocab.txt
# [2024-10-18 20:01:51,122] [    INFO] - tokenizer config file saved in C:\Users\biang\.paddlenlp\models\chinese-electra-small\tokenizer_config.json
# [2024-10-18 20:01:51,123] [    INFO] - Special tokens file saved in C:\Users\biang\.paddlenlp\models\chinese-electra-small\special_tokens_map.json
# D:\NLP_email\.venv\lib\site-packages\paddlenlp\transformers\tokenizer_utils_base.py:2293: FutureWarning: The `max_seq_len` argument is deprecated and will be removed in a future version, please use `max_length` instead.
#   warnings.warn(
# D:\NLP_email\.venv\lib\site-packages\paddlenlp\transformers\tokenizer_utils_base.py:1865: UserWarning: Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
#   warnings.warn(
# W1018 20:01:51.188654 19492 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.6, Runtime API Version: 11.7
# W1018 20:01:51.192656 19492 gpu_resources.cc:149] device: 0, cuDNN Version: 8.7.
# Traceback (most recent call last):
#   File "D:\NLP_email\pretrained_models\deploy\python\predict.py", line 210, in <module>
#     results = predictor.predict(
#   File "D:\NLP_email\pretrained_models\deploy\python\predict.py", line 163, in predict
#     self.predictor.run()
# ValueError: In user code:
#
#     File "D:\NLP_email\pretrained_models\export_model.py", line 55, in <module>
#       paddle.jit.save(model, args.output_path)
#     File "D:\NLP_email\.venv\lib\site-packages\decorator.py", line 232, in fun
#       return caller(func, *(extras + args), **kw)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\wrapped_decorator.py", line 25, in __impl__
#       return wrapped_func(*args, **kwargs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\api.py", line 752, in wrapper
#       func(layer, path, input_spec, **configs)
#     File "D:\NLP_email\.venv\lib\site-packages\decorator.py", line 232, in fun
#       return caller(func, *(extras + args), **kw)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\wrapped_decorator.py", line 25, in __impl__
#       return wrapped_func(*args, **kwargs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\dygraph\base.py", line 75, in __impl__
#       return func(*args, **kwargs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\api.py", line 1043, in save
#       static_func.concrete_program_specify_input_spec(
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\dy2static\program_translator.py", line 709, in concrete_program_specify_input_spec
#       concrete_program, _ = self.get_concrete_program(
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\dy2static\program_translator.py", line 589, in get_concrete_program
#       concrete_program, partial_program_layer = self._program_cache[
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\dy2static\program_translator.py", line 1249, in __getitem__
#       self._caches[item_id] = self._build_once(item)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\dy2static\program_translator.py", line 1193, in _build_once
#       concrete_program = ConcreteProgram.from_func_spec(
#     File "D:\NLP_email\.venv\lib\site-packages\decorator.py", line 232, in fun
#       return caller(func, *(extras + args), **kw)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\wrapped_decorator.py", line 25, in __impl__
#       return wrapped_func(*args, **kwargs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\dygraph\base.py", line 75, in __impl__
#       return func(*args, **kwargs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\dy2static\program_translator.py", line 1063, in from_func_spec
#       outputs = static_func(*inputs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddlenlp\transformers\electra\modeling.py", line 853, in forward
#       sequence_output = self.electra(
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\nn\layer\layers.py", line 1256, in __call__
#       return self._dygraph_call_func(*inputs, **kwargs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\nn\layer\layers.py", line 1235, in _dygraph_call_func
#       outputs = self.forward(*inputs, **kwargs)
#     File "D:\NLP_email\.venv\lib\site-packages\paddlenlp\transformers\electra\modeling.py", line 450, in forward
#       if attention_mask is None:
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\dy2static\convert_operators.py", line 352, in convert_ifelse
#       out = _run_py_ifelse(
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\jit\dy2static\convert_operators.py", line 429, in _run_py_ifelse
#       py_outs = true_fn() if pred else false_fn()
#     File "D:\NLP_email\.venv\lib\site-packages\paddlenlp\transformers\electra\modeling.py", line 451, in forward
#       attention_mask = paddle.unsqueeze(
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\layers\math_op_patch.py", line 445, in __impl__
#       current_block(self).append_op(
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\framework.py", line 4013, in append_op
#       op = Operator(
#     File "D:\NLP_email\.venv\lib\site-packages\paddle\fluid\framework.py", line 2781, in __init__
#       for frame in traceback.extract_stack():
#
#     InvalidArgumentError: The type of data we are trying to retrieve (int64) does not match the type of data (int32) currently contained in the container.
#       [Hint: Expected dtype() == phi::CppTypeToDataType<T>::Type(), but received dtype():7 != phi::CppTypeToDataType<T>::Type():9.] (at ..\paddle\phi\core\dense_tensor.cc:166)
#       [operator < equal > error]

# %% [markdown]
# 预测结果如下
# ```python
# Data: 低点代开发票 	 Label: 垃圾邮件
# Data: 深圳协恒实业有限公司 	 Label: 垃圾邮件
# Data: 帮帮忙啊 	 Label: 正常邮件
# ```

# %% [markdown]
# # 参考资料
# - [RoBERTa: A Robustly Optimized BERT Pretraining Approach](https://arxiv.org/abs/1907.11692)
# - [RoBERTa项目中文地址：https://github.com/brightmart/roberta_zh](https://github.com/brightmart/roberta_zh)
# - [RoBERTa模型原理总结](https://zhuanlan.zhihu.com/p/347861417)
# - [RoBERTa 详解](https://zhuanlan.zhihu.com/p/103205929)

# %% [markdown]
# # 小结
#
# 1. 其实只要弄清了最关键的一步，即如何自定义数据集，使用PaddleNLP库进行文本分类的迁移学习还是非常方便的。特别要注意的，就是不同的自定义数据集方法返回结果的差异：
# 过去，一般是这样……
# ```python
# 训练集数据：[['非财务经理的财务管理 沙盘模拟', '0'], ['低点代开发票', '0'], ['一边上网冲浪 一边赚钱 何乐而不为', '0']]
#
# 验证集数据:[['问一部魏宗万的电影名称', '1'], ['低点代开发票', '0'], ['深圳协恒实业有限公司', '0']]
#
# 测试集数据:[['公司业务 代开发票', '0'], ['合作', '0'], ['公司业务 优惠发票', '0']]
# ```
# 现在，PaddleNLP模型库推荐的是这样……
# ```python
# 训练集数据：[{'text': '低点代开发票', 'label': '0'}, {'text': '一边上网冲浪 一边赚钱 何乐而不为', 'label': '0'}, {'text': '优惠代开各种发票', 'label': '0'}]
#
# 验证集数据:[{'text': '低点代开发票', 'label': '0'}, {'text': '深圳协恒实业有限公司', 'label': '0'}, {'text': '帮帮忙啊', 'label': '1'}]
#
# 测试集数据:[{'text': '合作', 'label': '0'}, {'text': '公司业务 优惠发票', 'label': '0'}, {'text': '业务合作', 'label': '0'}]
# ```
# 2. 中文邮件短标题的分类效果能达到98.3%以上，比英文邮件的92%高出不少，这有可能是数据集的问题，当然，有可能是这个场景下，确实英文垃圾邮件不太明显？（这是非常有可能的，注册过几个外网网站你就知道，即使是那些国外大厂，也超爱发各种广告邮件），但是我们也应当意识到，由于数据集有限，中文邮件短标题面对当前的实际场景，效果可能会比较一般，这个模型只是针对当前数据集的较优方案。开发适合用户需要的垃圾邮件分类器，肯定还是需要整合用户自己的邮件分类数据和标注。
